# %% [markdown]
# # Morfologická analýza
#
# V tomto notebooku naprogramujeme jednoduchý morfologický analyzátor. Budeme se soustředit pouze na značkování slovních druhů, další gramatické informace jako rod, číslo, čas apod. řešit nebudeme. K řešení použijeme pouze základní funkce Pythonu a knihovnu re pro regulární výrazy.
#
# Morfologická analýza je důležitým komponentem např. v korpusové lingvistice. Podle webu [Českého národního korpusu](https://wiki.korpus.cz/doku.php/pojmy:morfologicka_analyza) se morfologická analýza skládá z přiřazení lemmat (slovníkových podob hesel) a morfologických značek ke všem slovním tvarům.
#
# Morfologické značky nesou všechny gramatické informace, jaké lze u daného slovního tvaru určit. Přičemž tyto značky se v různých korpusech mohou výrazně lišit (srv. "pražské" a "brněnské" značky), případně nemusí obsahovat úplně všechny gramatické informace.
#
# Na morfologickou analýzu navazuje desambiguace (zjednoznačnění), tj. odstranění homonymie. Tím se ale v tomto notebooku zaobírat nebudeme.
#
# ## 2 S čím budeme pracovat
#
# ### 2.1 re
#
# V tomto notebooku použijeme modul re, který slouží pro práci s regulárními výrazy.
#
# Více informací na [re](https://docs.python.org/3/library/re.html) nebo [Programiz](https://www.programiz.com/python-programming/regex).
#
# Pro připomenutí regulárních výrazů vám může pomoct tento [cheatsheet](https://cheatography.com/davechild/cheat-sheets/regular-expressions/). Než výrazy implementujete do svého kódu, můžete si jejich funkčnost vyzkoušet např. na [regex101](https://regex101.com/) (nezapomeňte si v levém boxu přepnout flavor na Python).
#
# ### 2.2 Označkovaný text
#
# V tomto notebooku budeme pracovat jak s neoznačkovaným, tak s označkovaným textem. Pro označkování textu byl použit morfologický analyzátor [MorphoDita](http://lindat.mff.cuni.cz/services/morphodita/), výstup z analyzátoru byl poté upraven pro účely tohoto notebooku.
#
# ## 3 Instalace
#
# ### 3.1 re
#
# Modul re je součástí tzv. The Python Standard Library (standarní knihovny Pythonu), není tedy nutné nic instalovat.
#
# Více informací na [The Python Standard Library](https://docs.python.org/3/library/).
#
# ### 3.2 MorphoDita
#
# Pokud budete chtít, nemusíte využít předpřipravený text, ale můžete si jako vzorový text vybrat vlastní. K označkování textu použijeme analyzátor MorphoDita, který je dostupný jako webová aplikace [zde](http://lindat.mff.cuni.cz/services/morphodita/). Není tedy třeba nic instalovat.
#
# ## 4 Import knihoven a modulů
#
# Než budeme moct začít s psaním programu, musíme importovat všechny knihovny a moduly, které budeme potřebovat. Patří mezi ně:
#
# - re
#
# Spusťte následující buňku, modul re se importuje.
#
# **Poznámka:** Po každém zavření a otevření notebooku je nutné všechen kód (tj. i importování) spustit znovu. Výsledky sice zůstanou zobrazeny, obsah proměnných však v paměti nezůstává.

# %%
import re #importuj knihovnu re

# %% [markdown]
# Než začneme programovat, naučíme se, jak pomocí Pythonu pracovat se soubory. Ukážeme si přepsání obsahu souboru a přidání dalších řádků textu. Zjistíme, jak vytvořit úplně nový soubor. V další sekci si v krátkosti zopakujeme regulární výrazy. Tyto dovednosti využijeme při psaní analyzátoru.
#
# ## 5 Práce se soubory
#
# ### 5.1 Otevření souboru
#
# K otevření souboru v Pythonu slouží metoda `open`. Požaduje dva parametry:
#
# 1. název souboru (pokud se soubor nachází ve stejné složce jako program, stačí pouze název s formátem, pokud se soubor nachází jinde, je nutné specifikovat celou cestu),
# 2. mód, v jakém se soubor otevře (v našem případě `r`= read = ke čtení).
#
# Pokud si budete chtít otevření souboru vyzkoušet, zkontrolujte, že do příkazu níže zadáváte existující soubor s platnou cestou.

# %%
txt = open('uryvek.txt', 'r') #otevři soubor ke čtení

# %% [markdown]
# Všimněte si, že metoda `open` sice otevře daný soubor a uloží jej do proměnné, nevypíše ale obsah souboru.

# %%
txt #vypiš proměnnou txt
# Out:
# <_io.TextIOWrapper name='uryvek.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# ### 5.2 Přečtení souboru
#
# K výpisu obsahu proměnné musíme použít metodu `read`, která přečte celý soubor (případně metodu `readlines`, která čte po jednom řádku).

# %%
txt2 = txt.read() #přečti obsah proměnné txt2

# %%
txt2 #vypiš proměnnou txt2
# Out:
# 'Zprava:\n\n      V polovině ledna se v médiích objevila zpráva, že předsedkyně Poslanecké sněmovny Markéta Pekarová Adamová shání stážistu. „Stážistce či stážistovi nabízíme aktivní zapojení do práce v oblasti mezinárodních vztahů a diplomatických aktivit předsedkyně, seznámení se s chodem kanceláře předsedkyně a také s prostorami a fungováním Poslanecké sněmovny,“ stojí v inzerátu.\n\n'

# %%
txt3 = txt.readlines(1) #přečti jeden řádek

# %%
txt3 #vypiš proměnnou txt3
# Out:
# ['Zprava:\n']

# %% [markdown]
# ### 5.3 Zavření souboru
#
# K zavření souboru slouží metoda `close`. Zavírání souborů je dobrou praxí, která nám zaručí, že si nepoškodíme soubory, se kterými pracujeme. Více na [Stack Overflow](https://stackoverflow.com/questions/7395542/is-explicitly-closing-files-important).
#
# **Poznámka:** Pokud proměnnou přepíšete, tj. proměnná již neobsahuje samotný soubor, ale např. text uložený v řetězci, zavřít soubor vám nepůjde.

# %%
txt.close() #zavři soubor uložený v proměnné txt

# %% [markdown]
# #### 5.3.1 With open
#
# Metoda `with open` se o zavření souboru postará automaticky. Více třeba ve vláknu na [Stack Overflow](https://stackoverflow.com/questions/9282967/how-to-open-a-file-using-the-open-with-statement).
#
# ### 5.4 Zápis do již existujícího souboru
#
# Pokud chceme do souboru i zapisovat, musíme změnit mód, ve kterém soubor otevřeme. V sekci 5.1 jsme použili mód `r` (ke čtení). Pro zápis si můžeme vybrat ze dvou módů:
#
# 1. `a` = append = další text připojí na konec souboru
# 2. `w` = write = přepíše existující obsah souboru

# %%
txt = open('uryvek.txt', 'a') #otevři soubor v módu append

# %% [markdown]
# Po použití těchto dvou módů můžeme použít metodu `write` k zápisu dalších řetězců do souboru.

# %%
txt.write('Nový text') #zapiš do souboru txt řetězec Nový text
# Out:
# 10

# %%
txt.read() #přečti obsah proměnné txt
# Out:
# 'Zprava:\n\n      V polovině ledna se v médiích objevila zpráva, že předsedkyně Poslanecké sněmovny Markéta Pekarová Adamová shání stážistu. „Stážistce či stážistovi nabízíme aktivní zapojení do práce v oblasti mezinárodních vztahů a diplomatických aktivit předsedkyně, seznámení se s chodem kanceláře předsedkyně a také s prostorami a fungováním Poslanecké sněmovny,“ stojí v inzerátu.\n\nNový text'

# %% [markdown]
# ### 5.5 Vytvoření nového souboru
#
# K vytvoření nového souboru neexistuje specifická funkce, použijeme metodu `open` s některým ze třech módů: `x`, `a`, `w`.
#
# S `a` a `w` jsme se setkali v předchozí sekci. Jejich použití od nového módu `x` = create se liší v chybových hláškách. Módy `a` a `w` vytvoří nový soubor pouze, pokud již neexistuje. Pokud soubor se stejným jménem existuje, nestane se nic, ale nedostanete ani chybovou hlášku. Oproti tomu mód `x` vytvoří nový soubor pouze pokud soubor se stejným jménem již neexistuje. Pokud takový soubor existuje, dostanete chybovou hlášku.

# %%
txt = open('uryvek2.txt', 'w') #vytvoř nový soubor pomocí módu write

# %%
txt = open('uryvek2.txt', 'a') #vytvoř nový soubor pomocí módu append (soubor již existuje, nic se nestane a
                               #a ani nedostaneme chybovou hlášku)

# %%
txt = open('uryvek2.txt', 'x') #vytvoř nový soubor pomocí módu create (soubor již existuje, dostaneme chybovou
                               #hlášku)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_11486/178794835.py in <module>
# ----> 1 txt = open('uryvek2.txt', 'x')
#
# FileExistsError: [Errno 17] File exists: 'uryvek2.txt'

# %% [markdown]
# Přehled všech metod a módů práce se souboru naleznete např. na [Geeks for Geeks](https://www.geeksforgeeks.org/writing-to-file-in-python/).
#
# ## 6 Regulární výrazy
#
# Regulární výrazy slouží jako vzor pro vyhledávání v textu. V Pythonu díky knihovně re a různým funkcím můžeme textové řetězce nejen vyhledávat, ale i modifikovat nebo je nahrazovat za jiné řetězce. V tokenizátoru využijeme hlavně vyhledávání, pokud budeme chtít nalézt např. interpunkci.
#
# K vyhledávání slouží v Pythonu funkce `search`. Tato funkce požaduje dva parametry, regulární výraz a text, ve kterém se má vyhledávat.

# %%
sent = 'Jasno nebo skoro jasno.' #ulož tetxový řetězec do proměnné
sent2 = 'Maximální teploty 10 až 14 °C. ' #ulož textový řetězec do proměnné

# %%
reg = re.search(r'\d', sent) #vyhledej první číslici v textu sent

# %%
print(reg) #vypiš výsledek hledání
# Out:
# None

# %%
reg = re.search(r'\d', sent2) #vyhledej první číslici v textu sent2

# %%
print(reg) #vypiš výsledek hledání
# Out:
# <re.Match object; span=(18, 19), match='1'>

# %% [markdown]
# Pokud funkce `search` nenalezne text, který by korespondoval s regulárním výrazem, vrátí hodnotu `None`. Pokud naopak nalezne shodu, vrátí index prvního výskytu (`span`) a kolikrát se daný výraz v textu vyskytuje (`match`). V případě, že budeme chtít nalézt všechny textové řetězce, nejenom první, musíme použít funkci `findall`.
#
# Efektivnějším způsobem, jak pracovat s regulárními výrazy, je uložit si je do proměnné. A to zejména, pokud stejné výrazy používáme na různých místech v kódu. Výraz pak v řešení změníme pouze jednou. K tomu slouží funkce `compile`.

# %%
pattern = re.compile(r'\d') #zkompiluj regulární výraz pro vyhledání číslic

# %%
reg2 = re.findall(pattern, sent2) #vyhledej všechny číslice v texti sent2

# %%
print(reg2) #vypiš výsledek hledání
# Out:
# ['1', '0', '1', '4']

# %% [markdown]
# **Poznámka:** r ve výrazu `r'\d'` slouží v Pythonu k upřesnění, že se nejedná o běžný řetězec, ale regulární výraz. V některých případech vám regulární výrazy budou fungovat i bez r, je ale lepší jej před výrazem použít.
#
# Další funkce naleznete v [dokumentaci ke knihovně re](https://docs.python.org/3/library/re.html), další informace a užitečné odkazy naleznete v sekci 3 tohoto notebooku.

# %% [markdown]
# ## Příprava textu

# %%
with open ('data/morphodita-processed.txt', 'r') as txt:
    txt = txt.read()

# %%
txt
# Out:
# 'Když\tkdyž\tJ,-------------\nmi\tjá\tPH-S3--1-------\nbylo\tbýt\tVpNS---XR-AA---\nšest\tšest`6\tCn-S1----------\nlet\trok\tNNNP2-----A----\n,\t,\tZ:-------------\nviděl\tvidět\tVpYS---XR-AA---\njsem\tbýt\tVB-S---1P-AA---\njednou\tjednou-2\tDb-------------\nnádherný\tnádherný\tAAIS1----1A----\nobrázek\tobrázek\tNNIS1-----A----\nv\tv-1\tRR--6----------\nknize\tkniha\tNNFS6-----A----\no\to-1\tRR--6----------\npralese\tprales\tNNIS6-----A----\n,\t,\tZ:-------------\nkterá\tkterý\tP4FS1----------\nse\tse_^(zvr._zájmeno/částice)\tP7-X4----------\njmenovala\tjmenovat_:T_:W\tVpQW---XR-AA---\nPříběhy\tpříběh\tNNIP1-----A----\nze\tz-1\tRV--2----------\nživota\tživot\tNNIS2-----A----\n.\t.\tZ:-------------\n\nNa\tna-1\tRR--6----------\nobrázku\tobrázek\tNNIS6-----A----\nbyl\tbýt\tVpYS---XR-AA---\nhroznýš\throznýš\tNNMS1-----A----\n,\t,\tZ:-------------\njak\tjak-3\tDb-------------\npolyká\tpolykat_:T\tVB-S---3P-AA---\nšelmu\tšelma\tNNFS4-----A----\n.\t.\tZ:-------------\n\nTohle\ttenhle\tPDNS1----------\nje\tbýt\tVB-S---3P-AA---\nkopie\tkopie\tNNFS1-----A----\nkresby\tkresba\tNNFS2-----A----\n:\t:\tZ:-------------\nV\tv-1\tRR--6----------\nknížce\tknížka\tNNFS6-----A----\nstálo\tstát-3_^(někdo/něco_stojí,_např._na_nohou)\tVpNS---XR-AA---\n:\t:\tZ:-------------\n„\t„\tZ:-------------\nHroznýši\throznýš\tNNMP1-----A----\nsvou\tsvůj-1_^(přivlast.)\tP8FS4---------1\nkořist\tkořist\tNNFS4-----A----\nnežvýkají\tžvýkat_:T\tVB-P---3P-NA---\n,\t,\tZ:-------------\npolykají\tpolykat_:T\tVB-P---3P-AA---\nji\ton-1\tPPFS4--3-------\ncelou\tcelý\tAAFS4----1A----\n.\t.\tZ:-------------\n\nPotom\tpotom\tDb-------------\nse\tse_^(zvr._zájmeno/částice)\tP7-X4----------\nnemohou\tmoci_^(mít_možnost_[něco_dělat])\tVB-P---3P-NA--1\nani\tani-1\tJ^-------------\nhnout\thnout\tVf--------A----\na\ta-1\tJ^-------------\ncelého\tcelý\tAAMS4----1A----\npůl\tpůl-2\tNNFS4-----A----\nroku\trok\tNNIS2-----A---1\nspí\tspát\tVB-P---3P-AA---\na\ta-1\tJ^-------------\ntráví\ttrávit_:T\tVB-P---3P-AA---\n.\t.\tZ:-------------\n“\t“\tZ:-------------\nHodně\thodně-2_^(nezlobivý)_(*3ý-2)\tDg-------1A----\njsem\tbýt\tVB-S---1P-AA---\ntehdy\ttehdy\tDb-------------\npřemýšlel\tpřemýšlet_:T\tVpYS---XR-AA---\no\to-1\tRR--6----------\ndobrodružstvích\tdobrodružství\tNNNP6-----A----\nv\tv-1\tRR--6----------\ndžungli\tdžungle\tNNFS6-----A----\na\ta-1\tJ^-------------\ntaké\ttaké\tDb-------------\nse\tse_^(zvr._zájmeno/částice)\tP7-X4----------\nmně\tjá\tPP-S3--1-------\npodařilo\tpodařit_:W\tVpNS---XR-AA---\nnakreslit\tnakreslit_:W\tVf--------A----\npastelkou\tpastelka\tNNFS7-----A----\nprvní\tprvní\tCrFS4----------\nkresbu\tkresba\tNNFS4-----A----\n.\t.\tZ:-------------\n\nKresbu\tkresba\tNNFS4-----A----\nčíslo\tčíslo\tNNNS1-----A----\n1\t1\tC=-------------\n.\t.\tZ:-------------\n\nVypadala\tvypadat_:T\tVpQW---XR-AA---\ntakhle\ttakhle\tDb-------------\n:\t:\tZ:-------------\nUkázal\tukázat\tVpYS---XR-AA---\njsem\tbýt\tVB-S---1P-AA---\nsvé\tsvůj-1_^(přivlast.)\tP8NS4---------1\nveledílo\tveledílo_^(umělecké,_vědecké,...)\tNNNS4-----A----\ndospělým\tdospělý-2\tNNMP3-----A----\na\ta-1\tJ^-------------\nptal\tptát\tVpYS---XR-AA---\njsem\tbýt\tVB-S---1P-AA---\nse\tse_^(zvr._zájmeno/částice)\tP7-X4----------\njich\ton-1\tPPXP2--3-------\n,\t,\tZ:-------------\nnahání\tnahánět_:T\tVB-S---3P-AA---\n-\t-\tZ:-------------\nli\tli-1\tTT-------------\njim\ton-1\tPPXP3--3-------\nmá\tmít\tVB-S---3P-AA---\nkresba\tkresba\tNNFS1-----A----\nstrach\tstrach\tNNIS4-----A----\n.\t.\tZ:-------------\n\nOdpověděli\todpovědět\tVpMP---XR-AA---\nmi\tjá\tPH-S3--1-------\n:\t:\tZ:-------------\n„\t„\tZ:-------------\nProč\tproč\tDb-------------\nby\tbýt\tVc-------------\nklobouk\tklobouk\tNNIS1-----A----\nnaháněl\tnahánět_:T\tVpYS---XR-AA---\nstrach\tstrach\tNNIS4-----A----\n?\t?\tZ:-------------\n“\t“\tZ:-------------\nAle\tale\tJ^-------------\non\ton-1\tPPYS1--3-------\nto\tten\tPDNS4----------\nnebyl\tbýt\tVpYS---XR-NA---\nklobouk\tklobouk\tNNIS1-----A----\n.\t.\tZ:-------------\n\nByl\tbýt\tVpYS---XR-AA- ...

# %%
txt = re.sub('\t.*\t', ' ', txt)

# %%
print(txt)
# Out:
# Když J,-------------
# mi PH-S3--1-------
# bylo VpNS---XR-AA---
# šest Cn-S1----------
# let NNNP2-----A----
# , Z:-------------
# viděl VpYS---XR-AA---
# jsem VB-S---1P-AA---
# jednou Db-------------
# nádherný AAIS1----1A----
# obrázek NNIS1-----A----
# v RR--6----------
# knize NNFS6-----A----
# o RR--6----------
# pralese NNIS6-----A----
# , Z:-------------
# která P4FS1----------
# se P7-X4----------
# jmenovala VpQW---XR-AA---
# Příběhy NNIP1-----A----
# ze RV--2----------
# života NNIS2-----A----
# . Z:-------------
#
# Na RR--6----------
# obrázku NNIS6-----A----
# byl VpYS---XR-AA---
# hroznýš NNMS1-----A----
# , Z:-------------
# jak Db-------------
# polyká VB-S---3P-AA---
# šelmu NNFS4-----A----
# . Z:-------------
#
# Tohle PDNS1----------
# je VB-S---3P-AA---
# kopie NNFS1-----A----
# kresby NNFS2-----A----
# : Z:-------------
# V RR--6----------
# knížce NNFS6-----A----
# stálo VpNS---XR-AA---
# : Z:-------------
# „ Z:-------------
# Hroznýši NNMP1-----A----
# svou P8FS4---------1
# kořist NNFS4-----A----
# nežvýkají VB-P---3P-NA---
# , Z:-------------
# polykají VB-P---3P-AA---
# ji PPFS4--3-------
# celou AAFS4----1A----
# . Z:-------------
#
# Potom Db-------------
# se P7-X4----------
# nemohou VB-P---3P-NA--1
# ani J^-------------
# hnout Vf--------A----
# a J^-------------
# celého AAMS4----1A----
# půl NNFS4-----A----
# roku NNIS2-----A---1
# spí VB-P---3P-AA---
# a J^-------------
# tráví VB-P---3P-AA---
# . Z:-------------
# “ Z:-------------
# Hodně Dg-------1A----
# jsem VB-S---1P-AA---
# tehdy Db-------------
# přemýšlel VpYS---XR-AA---
# o RR--6----------
# dobrodružstvích NNNP6-----A----
# v RR--6----------
# džungli NNFS6-----A----
# a J^-------------
# také Db-------------
# se P7-X4----------
# mně PP-S3--1-------
# podařilo VpNS---XR-AA---
# nakreslit Vf--------A----
# pastelkou NNFS7-----A----
# první CrFS4----------
# kresbu NNFS4-----A----
# . Z:-------------
#
# Kresbu NNFS4-----A----
# číslo NNNS1-----A----
# 1 C=-------------
# . Z:-------------
#
# Vypadala VpQW---XR-AA---
# takhle Db-------------
# : Z:-------------
# Ukázal VpYS---XR-AA---
# jsem VB-S---1P-AA---
# své P8NS4---------1
# veledílo NNNS4-----A----
# dospělým NNMP3-----A----
# a J^-------------
# ptal VpYS---XR-AA---
# jsem VB-S---1P-AA---
# se P7-X4----------
# jich PPXP2--3-------
# , Z:-------------
# nahání VB-S---3P-AA---
# - Z:-------------
# li TT-------------
# jim PPXP3--3-------
# má VB-S---3P-AA---
# kresba NNFS1-----A----
# strach NNIS4-----A----
# . Z:-------------
#
# Odpověděli VpMP---XR-AA---
# mi PH-S3--1-------
# : Z:-------------
# „ Z:-------------
# Proč Db-------------
# by Vc-------------
# klobouk NNIS1-----A----
# naháněl VpYS---XR-AA---
# strach NNIS4-----A----
# ? Z:-------------
# “ Z:-------------
# Ale J^-------------
# on PPYS1--3-------
# to PDNS4----------
# nebyl VpYS---XR-NA---
# klobouk NNIS1-----A----
# . Z:-------------
#
# Byl VpYS---XR-AA---
# to PDNS1----------
# hroznýš NNMS1-----A----
# , Z:-------------
# jak Db-------------
# zažívá VB-S---3P-AA---
# slona NNMS4-----A----
# . Z:-------------
#
# Nakreslil VpYS---XR-AA---
# jsem VB-S---1P-AA---
# tedy J^-------------
# vnitřek NNIS4-----A----
# hroznýše NNMS2-----A----
# , Z:-------------
# aby J,-------------
# to PDNS4----------
# dospělí NNMP1-----A----
# pochopili VpMP---XR-AA---
# . Z:-------------
#
# Oni PPMP1--3-------
# totiž J^-------------
# potřebují VB-P---3P-AA---
# vždycky Db--------A----
# nějaká PZNP4----------
# vysvětlení NNNP4-----A----
# . Z:-------------
#
# Má VB-S---3P-AA---
# kresba NNFS1-----A----
# číslo NNNS4-----A----
# 2 C=-------------
# vypadala VpQW---XR-AA---
# takhle Db-------------
# : Z:-------------
# Dospělí AAMP1----1A----
# mi PH-S3--1-------
# však J^-------------
# poradili VpMP---XR-AA---
# , Z:-------------
# aby J,-------------
# nechal VpYS---XR-AA---
# toho PDZS2----------
# kreslení NNNS4-----A----
# otevřených AAMP2----1A----
# a J^-------------
# zavřených AAMP2----1A----
# hroznýšů NNMP2-----A----
# a J^-------------
# zajímal VpYS---XR-AA---
# se P7-X4----------
# raději Dg-------2A----
# o RR--4----------
# zeměpis NNIS4-----A----
# , Z:-------------
# počty NNIP4-----A----
# a J^-------------
# mluvnici NNFS4-----A----
# . Z:-------------
#
# Tak Db-------------
# se P7-X4----------
# stalo VpNS---XR-AA---
# , Z:-------------
# že J,-------------
# jsem VB-S---1P-AA---
# se P7-X4----------
# v RR--6----------
# šesti Cn-P6----------
# letech NNNP6-----A----
# vzdal VpYS---XR-AA---
# skvělé AAFS2----1A----
# malířské AAFS2----1A----
# kariéry NNFS2-----A----
# . Z:-------------
#
# Neúspěch NNIS1-----A----
# mé PSFS2-S1------1
# kresby NNFS2-----A----
# číslo NNNS1-----A----
# 1 C=-------------
# a J^-------------
# kresby NNFP1-----A----
# číslo NNNS1-----A----
# 2 C=-------------
# mě PH-S4--1-------
# odradil VpYS---XR-AA---
# . Z:-------------
#
# Dospělí AAMP1----1A----
# sami PLMP1----------
# nikdy Db-------------
# nic PW--4----------
# nechápou VB-P---3P-NA---
# a J^-------------
# děti NNFP1-----A----
# to PDNS4----------
# hrozně Dg-------1A----
# unavuje VB-S---3P-AA---
# , Z:-------------
# stále Db-------------
# a J^-------------
# stále Db-------------
# jim PPXP3--3-------
# něco PZ--4----------
# vysvětlovat Vf--------A----
# . Z:-------------
#
# Musel VpYS---XR-AA---
# jsem VB-S---1P-AA---
# si P7-X3----------
# tedy J^-------------
# vybrat Vf--------A----
# jiné AANS4----1A----
# povolání NNNS4-----A----
# a J^-------------
# naučil VpYS---XR-AA---
# jsem VB-S---1P-AA---
# se P7-X4----------
# řídit Vf--------A----
# letadlo NNNS4-----A----
# . Z:-------------
#
# Létal VpYS---XR-AA---
# jsem VB-S---1P-AA---
# tak Db-------------
# trochu Db-------------
# po RR--6----------
# celém AAIS6----1A----
# světě NNIS6-----A----
# . Z:-------------
#
# A J^-------------
# pravda NNFS1-----A----
# je VB-S---3P-AA---
# , Z:-------------
# že J,-------------
# mi PH-S3--1-------
# zeměpis NNIS1-----A----
# hodně Dg-------1A----
# posloužil VpYS---XR-AA---
# . Z:-------------
#
# Dovedl VpYS---XR-AA---
# jsem VB-S---1P-AA---
# na RR--4----------
# první CrIS4----------
# pohled NNIS4-----A----
# rozeznat Vf--------A----
# Čínu NNFS4-----A----
# od RR--2----------
# Arizony NNFS2-----A----
# . Z:-------------
#
# Je VB-S---3P-AA---
# to PDNS1----------
# velice Db-------------
# užitečné AANS1----1A----
# , Z:-------------
# když J,-------------
# člověk NNMS1-----A----
# v RR--6----------
# noci NNFS6-----A----
# zabloudí VB-S---3P-AA---
# . Z:-------------
#
# A J^-------------
# tak Db-------------
# jsem VB-S---1P-AA---
# se P7-X4----------
# v RR--6----------
# životě NNIS6-----A----
# setkal VpYS---XR-AA---
# se RV--7----------
# spoustou NNFS7-----A----
# vážných AAMP2----1A----
# lidí NNMP2-----A----
# . Z:-------------
#
# Žil VpYS---XR-AA---
# jsem VB-S---1P-AA---
# hodně Dg-------1A----
# s RR--7----------
# dospělými NNMP7-----A----
# , Z:-------------
# poznal VpYS---XR-AA---
# jsem VB-S---1P-AA---
# je PPXP4--3-------
# velice Db-------------
# zblízka Db-------------
# . Z:-------------
#
# Ale J^-------------
# mé PSNS1-S1------1
# mínění NNNS1-----A----
# o RR--6----------
# nich P5XP6--3-------
# se P7-X4----------
# valně Dg-------1A----
# nezměnilo VpNS---XR-NA---
# . Z:-------------
#
# Když J,-------------
# jsem VB-S---1P-AA---
# mezi RR--7----------
# nimi P5XP7--3-------
# potkal VpYS---XR-AA---
# někoho PZM-4----------
# , Z:-------------
# kdo PKM-1----------
# se P7-X4----------
# mi PH-S3--1-------
# zdál VpYS---XR-AA---
# trochu Db-------------
# bystrý AAMS1----1A----
# , Z:-------------
# ověřil VpYS---XR-AA---
# jsem VB-S---1P-AA---
# si P7-X3----------
# na RR--6----------
# něm P5ZS6--3-------
# svou P8FS4---------1
# zkušenost NNFS4-----A----
# s RR--7----------
# kresbou NNFS7-----A----
# číslo NNNS1-----A----
# 1 C=-------------
# , Z:-------------
# kterou P4FS4----------
# mám VB-S---1P-AA---
# stále Db-------------
# schovanou AAFS4----1A----
# . Z:-------------
#
# Chtěl VpYS---XR-AA---
# jsem VB-S---1P-AA---
# vědět Vf--------A----
# , Z:-------------
# je VB-S---3P-AA---
# - Z:-------------
# li TT-------------
# opravdu Db-------------
# chápavý AAIS1----1A----
# . Z:-------------
#
# Ale J^-------------
# vždycky Db--------A----
# mi PH-S3--1-------
# odpověděl VpYS---XR-AA---
# : Z:-------------
# „ Z:-------------
# To PDNS1----------
# je VB-S---3P-AA---
# klobouk NNIS1-----A----
# . Z:-------------
# “ Z:-------------
# Nepovídal VpYS---XR-NA---
# jsem VB-S---1P-AA---
# mu PHZS3--3-------
# tedy J^-------------
# ani J^-------------
# o RR--6----------
# hroznýších NNMP6-----A----
# , Z:-------------
# ani J^-------------
# o RR--6----------
# pralesích NNIP6-----A----
# , Z:-------------
# ani J^-------------
# o RR--6----------
# hvězdách NNFP6-----A----
# . Z:-------------
#
# Přizpůsobil VpYS---XR-AA---
# jsem VB-S---1P-AA---
# se P7-X4----------
# mu PHZS3--3-------
# . Z:-------------
#
# Mluvil VpYS---XR-AA---
# jsem VB-S---1P-AA---
# s RR--7----------
# ním P5ZS7--3-------
# o RR--6----------
# bridži NNIS6-----A----
# , Z:-------------
# golfu NNIS6-----A----
# , Z:-------------
# politice NNFS6-----A----
# a J^-------------
# o RR--6----------
# kravatách NNFP6-----A----
# . Z:-------------
#
# A J^-------------
# dospělý NNMS1-----A----
# byl VpYS---XR-AA---
# velice Db-------------
# spokojen ACYS------A----
# , Z:-------------
# že J,-------------
# poznal VpYS---XR-AA---
# tak Db-------------
# rozuumného AAMS4----1A----
# člověka NNMS4-----A----
# . Z:-------------
#
# Tak Db-------------
# jsem VB-S---1P-AA---
# žil VpYS---XR-AA---
# sám PLYS1----------
# a J^-------------
# neměl VpYS---XR-NA---
# jsem VB-S---1P-AA---
# nikoho PWM-4----------
# , Z:-------------
# s RR--7----------
# kým PKM-7----------
# bych Vc-S---1-------
# si P7-X3----------
# mohl VpYS---XR-AA---
# opravdu Db-------------
# popovídat Vf--------A----
# . Z:-------------
#
# Tu PDFS4----------
# se P7-X4----------
# mi PH-S3--1-------
# jednou Db-------------
# před RR--7----------
# šesti Cn-P7----------
# lety NNNP7-----A----
# v RR--6----------
# poušti NNFS6-----A----
# na RR--6----------
# Sahaře NNFS6-----A----
# porouchal VpYS---XR-AA---
# motor NNIS1-----A----
# . Z:-------------
#
# Něco PZ--1----------
# se P7-X4----------
# v RR--6----------
# něm P5ZS6--3-------
# polámalo VpNS---XR-AA---
# . Z:-------------
#
# A J^-------------
# poněvadž J,-------------
# jsem VB-S---1P-AA---
# neměl VpYS---XR-NA---
# s RR--7----------
# sebou P6-X7----------
# mechanika NNMS4-----A----
# ani J^-------------
# cestující AGMP4-----A----
# , Z:-------------
# chtěl VpYS---XR-AA---
# jsem VB-S---1P-AA---
# se P7-X4----------
# do RR--2----------
# té PDFS2----------
# nesnadné AAFS2----1N----
# opravy NNFS2-----A----
# pustit Vf--------A----
# sám PLYS1----------
# . Z:-------------
#
# Byla VpQW---XR-AA---
# to PDNS1----------
# pro RR--4----------
# mne PP-S4--1-------
# otázka NNFS1-----A----
# života NNIS2-----A----
# nebo J^-------------
# smrti NNFS2-----A----
# . Z:-------------
#
# Měl VpYS---XR-AA---
# jsem VB-S---1P-AA---
# pitnou AAFS4----1A----
# vodu NNFS4-----A----
# sotva Db-------------
# na RR--4----------
# týden NNIS4-----A----
# . Z:-------------
#
# První CrIS4----------
# večer NNIS4-----A----
# jsem VB-S---1P-AA---
# tedy J^-------------
# usnul VpYS---XR-AA---
# v RR--6----------
# písku NNIS6-----A----
# , Z:-------------
# na RR--4----------
# tisíc NNIS4-----A----
# mil NNIXX-----A---8
# daleko Dg-------1A----
# od RR--2----------
# jakékoliv PZFS2---------1
# obydlené AAFS2----1A----
# končiny NNFS2-----A----
# . Z:-------------
#
# Byl VpYS---XR-AA---
# jsem VB-S---1P-AA---
# opuštěnější AAMS1----2A----
# než J,-------------
# trosečník NNMS1-----A----
# na RR--6----------
# voru NNIS6-----A----
# uprostřed Db-------------
# oceánu NNIS2-----A----
# . Z:-------------
#
# Dovedete VB-P---2P-AA---
# si P7-X3----------
# proto J^-------------
# představit Vf--------A----
# , Z:-------------
# jaké P4NS1----------
# bylo VpNS---XR-AA---
# mé PSNS1-S1------1
# překvapení NNNS1-----A----
# , Z:-------------
# když J,-------------
# mě PH-S4--1-------
# na RR--6----------
# úsvitě NNIS6-----A----
# probudil VpYS---XR-AA---
# zvláštní AAIS4----1A----
# hlásek NNIS4-----A----
# : Z:-------------
# „ Z:-------------
# Prosím VB-S---1P-AA---
# pěkně Dg-------1A----
# . Z:-------------
# . Z:-------------
# . Z:-------------
# nakresli Vi-S---2--A----
# mi PH-S3--1-------
# beránka NNMS4-----A----
# . Z:-------------
# . Z:-------------
# . Z:-------------
# “ Z:-------------
# „ Z:-------------
# Cože PQ--4----------
# ? Z:-------------
# “ Z:-------------
# „ Z:-------------
# Nakresli Vi-S---2--A----
# mi PH-S3--1-------
# beránka NNMS4-----A----
# . Z:-------------
# . Z:-------------
# . Z:-------------
# “ Z:-------------
# Vyskočil VpYS---XR-AA---
# jsem VB-S---1P-AA---
# , Z:-------------
# jako J,-------------
# by Vc-------------
# do RR--2----------
# mne PP-S2--1-------
# hrom NNIS1-----A----
# uhodil VpYS---XR-AA---
# . Z:-------------
#
# Dobře Dg-------1A----
# jsem VB-S---1P-AA---
# si P7-X3----------
# protřel VpYS---XR-AA---
# oči NNFP4-----A----
# . Z:-------------
#
# Pozorně Dg-------1A----
# jsem VB-S---1P-AA---
# se P7-X4----------
# podíval VpYS---XR-AA---
# a J^-------------
# spatřil VpYS---XR-AA---
# jsem VB-S---1P-AA---
# prazvláštního AAMS4----1A----
# človíčka NNMS4-----A----
# , Z:-------------
# který P4YS1----------
# si P7-X3----------
# mě PH-S4--1-------
# vážně Dg-------1A----
# prohlížel VpYS---XR-AA---
# . Z:-------------
#
# Toto PDNS1----------
# je VB-S---3P-AA---
# jeho PSXXXZS3-------
# nejlepší AAIS4----3A----
# portrét NNIS4-----A----
# , Z:-------------
# jaký P4IS4----------
# se P7-X4----------
# mi PH-S3--1-------
# podařilo VpNS---XR-AA---
# později Dg-------2A----
# nakreslit Vf--------A----
# . Z:-------------
#
# Má PSFS1-S1------1
# kresba NNFS1-----A----
# ovšem TT-------------
# není VB-S---3P-NA---
# zdaleka Db-------------
# tak Db-------------
# půvabná AAFS1----1A----
# jako J,-------------
# model NNIS1-----A----
# . Z:-------------
#
# Ale J^-------------
# za RR--4----------
# to PDNS4----------
# já PP-S1--1-------
# nemohu VB-S---1P-NA--1
# . Z:-------------
#
# Dospělí NNMP1-----A----
# mě PH-S4--1-------
# odradili VpMP---XR-AA---
# od RR--2----------
# malířské AAFS2----1A----
# kariéry NNFS2-----A----
# , Z:-------------
# když J,-------------
# mi PH-S3--1-------
# bylo VpNS---XR-AA---
# šest Cn-S1----------
# let NNNP2-----A----
# , Z:-------------
# a J^-------------
# proto J^-------------
# jsem VB-S---1P-AA---
# se P7-X4----------
# nenaučil VpYS---XR-NA---
# kreslit Vf--------A----
# nic PW--4----------
# jiného AANS2----1A----
# než J,-------------
# zavřené AAMP4----1A----
# a J^-------------
# otevřené AAMP4----1A----
# hroznýše NNMP4-----A----
# . Z:-------------
#
# Udiveně Dg-------1A----
# jsem VB-S---1P-AA---
# se P7-X4----------
# díval VpYS---XR-AA---
# na RR--4----------
# ten PDIS4----------
# zjev NNIS4-----A----
# . Z:-------------
#
# Považte Vi-P---2--A----
# jen TT-------------
# , Z:-------------
# že J,-------------
# jsem VB-S---1P-AA---
# byl VpYS---XR-AA---
# na RR--4----------
# tisíc ClXS2----------
# mil NNIS4-----A----
# od RR--2----------
# jakéhokoliv PZZS2---------1
# obydleného AAIS2----1A----
# kraje NNIS2-----A----
# . Z:-------------
#
# A J^-------------
# můj PSYS1-S1-------
# človíček NNMS1-----A----
# nevypadal VpYS---XR-NA---
# , Z:-------------
# jako J,-------------
# by Vc-------------
# zabloudil VpYS---XR-AA---
# ani J^-------------
# jako J,-------------
# by Vc-------------
# byl VpYS---XR-AA---
# na RR--4----------
# smrt NNFS4-----A----
# unavený AAMS1----1A----
# nebo J^-------------
# vyhladovělý AAMS1----1A----
# , Z:-------------
# polomrtvý AAMS1----1A----
# žízní NNFS7-----A----
# nebo J^-------------
# na RR--4----------
# smrt NNFS4-----A----
# vylekán VsYS---XX-AP---
# . Z:-------------
#
# Vůbec TT-------------
# nevypadal VpYS---XR-NA---
# jako J,-------------
# dítě NNNS1-----A----
# ztracené AANS1----1A----
# v RR--6----------
# poušti NNFS6-----A----
# , Z:-------------
# na RR--4----------
# tisíc NNIS4-----A----
# mil NNIXX-----A---8
# daleko Dg-------1A----
# od RR--2----------
# nějakého PZZS2----------
# obydleného AAIS2----1A----
# kraje NNIS2-----A----
# . Z:-------------
#
# Když J,-------------
# jsem VB-S---1P-AA---
# konečně Dg-------1A----
# byl VpYS---XR-AA---
# schopen ACYS------A----
# promluvit Vf--------A----
# , Z:-------------
# řekl VpYS---XR-AA---
# jsem VB-S---1P-AA---
# mu PHZS3--3-------
# : Z:-------------
# „ Z:-------------
# Ale J^-------------
# . Z:-------------
# . Z:-------------
# . Z:-------------
# co PQ--4----------
# tu Db-------------
# děláš VB-S---2P-AA---
# ? Z:-------------
# “ Z:-------------
# A J^-------------
# tu PDFS4----------
# mi PH-S3--1-------
# docela Db-------------
# tiše Dg-------1A----
# , Z:-------------
# jako J,-------------
# něco PZ--4----------
# nesmírně Dg-------1N----
# vážného AANS2----1A----
# , Z:-------------
# opakoval VpYS---XR-AA---
# : Z:-------------
# „ Z:-------------
# Prosím VB-S---1P-AA---
# pěkně Dg-------1A----
# . Z:-------------
# . Z:-------------
# . Z:-------------
# nakresli Vi-S---2--A----
# mi PH-S3--1-------
# beránka NNMS4-----A----
# . Z:-------------
# . Z:-------------
# . Z:-------------
# “ Z:-------------
# Když J,-------------
# stojíme VB-P---1P-AA---
# před RR--7----------
# příliš Db-------------
# velkou AAFS7----1A----
# záhadou NNFS7-----A----
# , Z:-------------
# neodvážíme VB-P---1P-NA---
# se P7-X4----------
# neuposlechnout Vf--------N----
# . Z:-------------
#
# Ačkoli J,-------------
# se P7-X4----------
# mi PH-S3--1-------
# to PDNS1----------
# zdálo VpNS---XR-AA---
# zde Db-------------
# – Z:-------------
# na RR--4----------
# tisíce NNIP4-----A----
# mil NNIS4-----A----
# ode RV--2----------
# všech PLXP2----------
# obydlených AANP2----1A----
# míst NNNP2-----A----
# a J^-------------
# v RR--6----------
# nebezpečí NNNS6-----A----
# smrti NNFS2-----A----
# – Z:-------------
# nesmyslné AANS1----1N----
# , Z:-------------
# vytáhl VpYS---XR-AA---
# jsem VB-S---1P-AA---
# z RR--2----------
# kapsy NNFS2-----A----
# list NNFP2-----A----
# papíru NNIS2-----A----
# plnící AGNS1-----A----
# pero NNNS1-----A----
# . Z:-------------
#
# Ale J^-------------
# tu Db-------------
# jsem VB-S---1P-AA---
# si P7-X3----------
# vzpomněl VpYS---XR-AA---
# , Z:-------------
# že J,-------------
# jsem VB-S---1P-AA---
# studoval VpYS---XR-AA---
# především Db-------------
# zeměpis NNIS4-----A----
# , Z:-------------
# dějepis NNIS4-----A----
# , Z:-------------
# počty NNIP4-----A----
# a J^-------------
# mluvnici NNFS4-----A----
# , Z:-------------
# a J^-------------
# řekl VpYS---XR-AA---
# jsem VB-S---1P-AA---
# človíčkovi NNMS3-----A----
# ( Z:-------------
# trochu Db-------------
# mrzutě Dg-------1A----
# ) Z:-------------
# , Z:-------------
# že J,-------------
# neumím VB-S---1P-NA---
# kreslit Vf--------A----
# . Z:-------------
#
# Odpověděl VpYS---XR-AA---
# mi PH-S3--1-------
# : Z:-------------
# „ Z:-------------
# To PDNS1----------
# nevadí VB-S---3P-NA---
# . Z:-------------
#
# Nakresli Vi-S---2--A----
# mi PH-S3--1-------
# beránka NNMS4-----A----
# . Z:-------------
# “ Z:-------------
# Poněvadž J,-------------
# jsem VB-S---1P-AA---
# nikdy Db-------------
# nekreslil VpYS---XR-NA---
# beránka NNMS4-----A----
# , Z:-------------
# nakreslil VpYS---XR-AA---
# jsem VB-S---1P-AA---
# mu PHZS3--3-------
# jednu ClFS4----------
# z RR--2----------
# těch PDXP2----------
# dvou ClXP2----------
# kreseb NNFP2-----A----
# , Z:-------------
# které P4FP4----------
# jsem VB-S---1P-AA---
# uměl VpYS---XR-AA---
# . Z:-------------
#
# Obrázek NNIS1-----A----
# zavřeného AAMS2----1A----
# hroznýše NNMS2-----A----
# . Z:-------------
#
# A J^-------------
# užasl VpYS---XR-AA--1
# jsem VB-S---1P-AA---
# , Z:-------------
# když J,-------------
# jsem VB-S---1P-AA---
# slyšel VpYS---XR-AA---
# , Z:-------------
# jak Db-------------
# mi PH-S3--1-------
# ten PDYS1----------
# človíček NNMS1-----A----
# povídá VB-S---3P-AA---
# : Z:-------------
# „ Z:-------------
# Ale J^-------------
# ne TT-------------
# , Z:-------------
# já PP-S1--1-------
# nechci VB-S---1P-NA---
# slona NNMS4-----A----
# v RR--6----------
# hroznýši NNMS6-----A----
# . Z:-------------
#
# Hroznýš NNMS1-----A----
# je VB-S---3P-AA---
# moc Db-------------
# nebezpečný AAIS1----1N----
# a J^-------------
# slon NNMS1-----A----
# zabere VB-S---3P-AA---
# hodně Dg-------1A----
# místa NNNS2-----A----
# . Z:-------------
#
# U RR--2----------
# mne PP-S2--1-------
# doma Db-------------
# je VB-S---3P-AA---
# všechno PLNS1----------
# malinké AANS1----1A----
# . Z:-------------
#
# Potřebuji VB-S---1P-AA--1
# beránka NNMS4-----A----
# . Z:-------------
#
# Nakresli Vi-S---2--A----
# mi PH-S3--1-------
# beránka NNMS4-----A----
# . Z:-------------
# “ Z:-------------
# Tak Db-------------
# jsem VB-S---1P-AA---
# tedy J^-------------
# kreslil VpYS---XR-AA---
# . Z:-------------

# %%
txt = txt.split('\n')

# %%
txt
# Out:
# ['Když J,-------------',
#  'mi PH-S3--1-------',
#  'bylo VpNS---XR-AA---',
#  'šest Cn-S1----------',
#  'let NNNP2-----A----',
#  ', Z:-------------',
#  'viděl VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'jednou Db-------------',
#  'nádherný AAIS1----1A----',
#  'obrázek NNIS1-----A----',
#  'v RR--6----------',
#  'knize NNFS6-----A----',
#  'o RR--6----------',
#  'pralese NNIS6-----A----',
#  ', Z:-------------',
#  'která P4FS1----------',
#  'se P7-X4----------',
#  'jmenovala VpQW---XR-AA---',
#  'Příběhy NNIP1-----A----',
#  'ze RV--2----------',
#  'života NNIS2-----A----',
#  '. Z:-------------',
#  '',
#  'Na RR--6----------',
#  'obrázku NNIS6-----A----',
#  'byl VpYS---XR-AA---',
#  'hroznýš NNMS1-----A----',
#  ', Z:-------------',
#  'jak Db-------------',
#  'polyká VB-S---3P-AA---',
#  'šelmu NNFS4-----A----',
#  '. Z:-------------',
#  '',
#  'Tohle PDNS1----------',
#  'je VB-S---3P-AA---',
#  'kopie NNFS1-----A----',
#  'kresby NNFS2-----A----',
#  ': Z:-------------',
#  'V RR--6----------',
#  'knížce NNFS6-----A----',
#  'stálo VpNS---XR-AA---',
#  ': Z:-------------',
#  '„ Z:-------------',
#  'Hroznýši NNMP1-----A----',
#  'svou P8FS4---------1',
#  'kořist NNFS4-----A----',
#  'nežvýkají VB-P---3P-NA---',
#  ', Z:-------------',
#  'polykají VB-P---3P-AA---',
#  'ji PPFS4--3-------',
#  'celou AAFS4----1A----',
#  '. Z:-------------',
#  '',
#  'Potom Db-------------',
#  'se P7-X4----------',
#  'nemohou VB-P---3P-NA--1',
#  'ani J^-------------',
#  'hnout Vf--------A----',
#  'a J^-------------',
#  'celého AAMS4----1A----',
#  'půl NNFS4-----A----',
#  'roku NNIS2-----A---1',
#  'spí VB-P---3P-AA---',
#  'a J^-------------',
#  'tráví VB-P---3P-AA---',
#  '. Z:-------------',
#  '“ Z:-------------',
#  'Hodně Dg-------1A----',
#  'jsem VB-S---1P-AA---',
#  'tehdy Db-------------',
#  'přemýšlel VpYS---XR-AA---',
#  'o RR--6----------',
#  'dobrodružstvích NNNP6-----A----',
#  'v RR--6----------',
#  'džungli NNFS6-----A----',
#  'a J^-------------',
#  'také Db-------------',
#  'se P7-X4----------',
#  'mně PP-S3--1-------',
#  'podařilo VpNS---XR-AA---',
#  'nakreslit Vf--------A----',
#  'pastelkou NNFS7-----A----',
#  'první CrFS4----------',
#  'kresbu NNFS4-----A----',
#  '. Z:-------------',
#  '',
#  'Kresbu NNFS4-----A----',
#  'číslo NNNS1-----A----',
#  '1 C=-------------',
#  '. Z:-------------',
#  '',
#  'Vypadala VpQW---XR-AA---',
#  'takhle Db-------------',
#  ': Z:-------------',
#  'Ukázal VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'své P8NS4---------1',
#  'veledílo NNNS4-----A----',
#  'dospělým NNMP3-----A----',
#  'a J^-------------',
#  'ptal VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'se P7-X4----------',
#  'jich PPXP2--3-------',
#  ', Z:-------------',
#  'nahání VB-S---3P-AA---',
#  '- Z:-------------',
#  'li TT-------------',
#  'jim PPXP3--3-------',
#  'má VB-S---3P-AA---',
#  'kresba NNFS1-----A----',
#  'strach NNIS4-----A----',
#  '. Z:-------------',
#  '',
#  'Odpověděli VpMP---XR-AA---',
#  'mi PH-S3--1-------',
#  ': Z:-------------',
#  '„ Z:-------------',
#  'Proč Db-------------',
#  'by Vc-------------',
#  'klobouk NNIS1-----A----',
#  'naháněl VpYS---XR-AA---',
#  'strach NNIS4-----A----',
#  '? Z:-------------',
#  '“ Z:-------------',
#  'Ale J^-------------',
#  'on PPYS1--3-------',
#  'to PDNS4----------',
#  'nebyl VpYS---XR-NA---',
#  'klobouk NNIS1-----A----',
#  '. Z:-------------',
#  '',
#  'Byl VpYS---XR-AA---',
#  'to PDNS1----------',
#  'hroznýš NNMS1-----A----',
#  ', Z:-------------',
#  'jak Db-------------',
#  'zažívá VB-S---3P-AA---',
#  'slona NNMS4-----A----',
#  '. Z:-------------',
#  '',
#  'Nakreslil VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'tedy J^-------------',
#  'vnitřek NNIS4-----A----',
#  'hroznýše NNMS2-----A----',
#  ', Z:-------------',
#  'aby J,-------------',
#  'to PDNS4----------',
#  'dospělí NNMP1-----A----',
#  'pochopili VpMP---XR-AA---',
#  '. Z:-------------',
#  '',
#  'Oni PPMP1--3-------',
#  'totiž J^-------------',
#  'potřebují VB-P---3P-AA---',
#  'vždycky Db--------A----',
#  'nějaká PZNP4----------',
#  'vysvětlení NNNP4-----A----',
#  '. Z:-------------',
#  '',
#  'Má VB-S---3P-AA---',
#  'kresba NNFS1-----A----',
#  'číslo NNNS4-----A----',
#  '2 C=-------------',
#  'vypadala VpQW---XR-AA---',
#  'takhle Db-------------',
#  ': Z:-------------',
#  'Dospělí AAMP1----1A----',
#  'mi PH-S3--1-------',
#  'však J^-------------',
#  'poradili VpMP---XR-AA---',
#  ', Z:-------------',
#  'aby J,-------------',
#  'nechal VpYS---XR-AA---',
#  'toho PDZS2----------',
#  'kreslení NNNS4-----A----',
#  'otevřených AAMP2----1A----',
#  'a J^-------------',
#  'zavřených AAMP2----1A----',
#  'hroznýšů NNMP2-----A----',
#  'a J^-------------',
#  'zajímal VpYS---XR-AA---',
#  'se P7-X4----------',
#  'raději Dg-------2A----',
#  'o RR--4----------',
#  'zeměpis NNIS4-----A----',
#  ', Z:-------------',
#  'počty NNIP4-----A----',
#  'a J^-------------',
#  'mluvnici NNFS4-----A----',
#  '. Z:-------------',
#  '',
#  'Tak Db-------------',
#  'se P7-X4----------',
#  'stalo VpNS---XR-AA---',
#  ', Z:-------------',
#  'že J,-------------',
#  'jsem VB-S---1P-AA---',
#  'se P7-X4----------',
#  'v RR--6----------',
#  'šesti Cn-P6----------',
#  'letech NNNP6-----A----',
#  'vzdal VpYS---XR-AA---',
#  'skvělé AAFS2----1A----',
#  'malířské AAFS2----1A----',
#  'kariéry NNFS2-----A----',
#  '. Z:-------------',
#  '',
#  'Neúspěch NNIS1-----A----',
#  'mé PSFS2-S1------1',
#  'kresby NNFS2-----A----',
#  'číslo NNNS1-----A----',
#  '1 C=-------------',
#  'a J^-------------',
#  'kresby NNFP1-----A----',
#  'číslo NNNS1-----A----',
#  '2 C=-------------',
#  'mě PH-S4--1-------',
#  'odradil VpYS---XR-AA---',
#  '. Z:-------------',
#  '',
#  'Dospělí AAMP1----1A----',
#  'sami PLMP1----------',
#  'nikdy Db-------------',
#  'nic PW--4----------',
#  'nechápou VB-P---3P-NA---',
#  'a J^-------------',
#  'děti NNFP1-----A----',
#  'to PDNS4----------',
#  'hrozně Dg-------1A----',
#  'unavuje VB-S---3P-AA---',
#  ', Z:-------------',
#  'stále Db-------------',
#  'a J^-------------',
#  'stále Db-------------',
#  'jim PPXP3--3-------',
#  'něco PZ--4----------',
#  'vysvětlovat Vf--------A----',
#  '. Z:-------------',
#  '',
#  'Musel VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'si P7-X3----------',
#  'tedy J^-------------',
#  'vybrat Vf--------A----',
#  'jiné AANS4----1A----',
#  'povolání NNNS4-----A----',
#  'a J^-------------',
#  'naučil VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'se P7-X4----------',
#  'řídit Vf--------A----',
#  'letadlo NNNS4-----A----',
#  '. Z:-------------',
#  '',
#  'Létal VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'tak Db-------------',
#  'trochu Db-------------',
#  'po RR--6----------',
#  'celém AAIS6----1A----',
#  'světě NNIS6-----A----',
#  '. Z:-------------',
#  '',
#  'A J^-------------',
#  'pravda NNFS1-----A----',
#  'je VB-S---3P-AA---',
#  ', Z:-------------',
#  'že J,-------------',
#  'mi PH-S3--1-------',
#  'zeměpis NNIS1-----A----',
#  'hodně Dg-------1A----',
#  'posloužil VpYS---XR-AA---',
#  '. Z:-------------',
#  '',
#  'Dovedl VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'na RR--4----------',
#  'první CrIS4----------',
#  'pohled NNIS4-----A----',
#  'rozeznat Vf--------A----',
#  'Čínu NNFS4-----A----',
#  'od RR--2----------',
#  'Arizony NNFS2-----A----',
#  '. Z:-------------',
#  '',
#  'Je VB-S---3P-AA---',
#  'to PDNS1----------',
#  'velice Db-------------',
#  'užitečné AANS1----1A----',
#  ', Z:-------------',
#  'když J,-------------',
#  'člověk NNMS1-----A----',
#  'v RR--6----------',
#  'noci NNFS6-----A----',
#  'zabloudí VB-S---3P-AA---',
#  '. Z:-------------',
#  '',
#  'A J^-------------',
#  'tak Db-------------',
#  'jsem VB-S---1P-AA---',
#  'se P7-X4----------',
#  'v RR--6----------',
#  'životě NNIS6-----A----',
#  'setkal VpYS---XR-AA---',
#  'se RV--7----------',
#  'spoustou NNFS7-----A----',
#  'vážných AAMP2----1A----',
#  'lidí NNMP2-----A----',
#  '. Z:-------------',
#  '',
#  'Žil VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'hodně Dg-------1A----',
#  's RR--7----------',
#  'dospělými NNMP7-----A----',
#  ', Z:-------------',
#  'poznal VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'je PPXP4--3-------',
#  'velice Db-------------',
#  'zblízka Db-------------',
#  '. Z:-------------',
#  '',
#  'Ale J^-------------',
#  'mé PSNS1-S1------1',
#  'mínění NNNS1-----A----',
#  'o RR--6----------',
#  'nich P5XP6--3-------',
#  'se P7-X4----------',
#  'valně Dg-------1A----',
#  'nezměnilo VpNS---XR-NA---',
#  '. Z:-------------',
#  '',
#  'Když J,-------------',
#  'jsem VB-S---1P-AA---',
#  'mezi RR--7----------',
#  'nimi P5XP7--3-------',
#  'potkal VpYS---XR-AA---',
#  'někoho PZM-4----------',
#  ', Z:-------------',
#  'kdo PKM-1----------',
#  'se P7-X4----------',
#  'mi PH-S3--1-------',
#  'zdál VpYS---XR-AA---',
#  'trochu Db-------------',
#  'bystrý AAMS1----1A----',
#  ', Z:-------------',
#  'ověřil VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'si P7-X3----------',
#  'na RR--6----------',
#  'něm P5ZS6--3-------',
#  'svou P8FS4---------1',
#  'zkušenost NNFS4-----A----',
#  's RR--7----------',
#  'kresbou NNFS7-----A----',
#  'číslo NNNS1-----A----',
#  '1 C=-------------',
#  ', Z:-------------',
#  'kterou P4FS4----------',
#  'mám VB-S---1P-AA---',
#  'stále Db-------------',
#  'schovanou AAFS4----1A----',
#  '. Z:-------------',
#  '',
#  'Chtěl VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'vědět Vf--------A----',
#  ', Z:-------------',
#  'je VB-S---3P-AA---',
#  '- Z:-------------',
#  'li TT-------------',
#  'opravdu Db-------------',
#  'chápavý AAIS1----1A----',
#  '. Z:-------------',
#  '',
#  'Ale J^-------------',
#  'vždycky Db--------A----',
#  'mi PH-S3--1-------',
#  'odpověděl VpYS---XR-AA---',
#  ': Z:-------------',
#  '„ Z:-------------',
#  'To PDNS1----------',
#  'je VB-S---3P-AA---',
#  'klobouk NNIS1-----A----',
#  '. Z:-------------',
#  '“ Z:-------------',
#  'Nepovídal VpYS---XR-NA---',
#  'jsem VB-S---1P-AA---',
#  'mu PHZS3--3-------',
#  'tedy J^-------------',
#  'ani J^-------------',
#  'o RR--6----------',
#  'hroznýších NNMP6-----A----',
#  ', Z:-------------',
#  'ani J^-------------',
#  'o RR--6----------',
#  'pralesích NNIP6-----A----',
#  ', Z:-------------',
#  'ani J^-------------',
#  'o RR--6----------',
#  'hvězdách NNFP6-----A----',
#  '. Z:-------------',
#  '',
#  'Přizpůsobil VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'se P7-X4----------',
#  'mu PHZS3--3-------',
#  '. Z:-------------',
#  '',
#  'Mluvil VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  's RR--7----------',
#  'ním P5ZS7--3-------',
#  'o RR--6----------',
#  'bridži NNIS6-----A----',
#  ', Z:-------------',
#  'golfu NNIS6-----A----',
#  ', Z:-------------',
#  'politice NNFS6-----A----',
#  'a J^-------------',
#  'o RR--6----------',
#  'kravatách NNFP6-----A----',
#  '. Z:-------------',
#  '',
#  'A J^-------------',
#  'dospělý NNMS1-----A----',
#  'byl VpYS---XR-AA---',
#  'velice Db-------------',
#  'spokojen ACYS------A----',
#  ', Z:-------------',
#  'že J,-------------',
#  'poznal VpYS---XR-AA---',
#  'tak Db-------------',
#  'rozuumného AAMS4----1A----',
#  'člověka NNMS4-----A----',
#  '. Z:-------------',
#  '',
#  'Tak Db-------------',
#  'jsem VB-S---1P-AA---',
#  'žil VpYS---XR-AA---',
#  'sám PLYS1----------',
#  'a J^-------------',
#  'neměl VpYS---XR-NA---',
#  'jsem VB-S---1P-AA---',
#  'nikoho PWM-4----------',
#  ', Z:-------------',
#  's RR--7----------',
#  'kým PKM-7----------',
#  'bych Vc-S---1-------',
#  'si P7-X3----------',
#  'mohl VpYS---XR-AA---',
#  'opravdu Db-------------',
#  'popovídat Vf--------A----',
#  '. Z:-------------',
#  '',
#  'Tu PDFS4----------',
#  'se P7-X4----------',
#  'mi PH-S3--1-------',
#  'jednou Db-------------',
#  'před RR--7----------',
#  'šesti Cn-P7----------',
#  'lety NNNP7-----A----',
#  'v RR--6----------',
#  'poušti NNFS6-----A----',
#  'na RR--6----------',
#  'Sahaře NNFS6-----A----',
#  'porouchal VpYS---XR-AA---',
#  'motor NNIS1-----A----',
#  '. Z:-------------',
#  '',
#  'Něco PZ--1----------',
#  'se P7-X4----------',
#  'v RR--6----------',
#  'něm P5ZS6--3-------',
#  'polámalo VpNS---XR-AA---',
#  '. Z:-------------',
#  '',
#  'A J^-------------',
#  'poněvadž J,-------------',
#  'jsem VB-S---1P-AA---',
#  'neměl VpYS---XR-NA---',
#  's RR--7----------',
#  'sebou P6-X7----------',
#  'mechanika NNMS4-----A----',
#  'ani J^-------------',
#  'cestující AGMP4-----A----',
#  ', Z:-------------',
#  'chtěl VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'se P7-X4----------',
#  'do RR--2----------',
#  'té PDFS2----------',
#  'nesnadné AAFS2----1N----',
#  'opravy NNFS2-----A----',
#  'pustit Vf--------A----',
#  'sám PLYS1----------',
#  '. Z:-------------',
#  '',
#  'Byla VpQW---XR-AA---',
#  'to PDNS1----------',
#  'pro RR--4----------',
#  'mne PP-S4--1-------',
#  'otázka NNFS1-----A----',
#  'života NNIS2-----A----',
#  'nebo J^-------------',
#  'smrti NNFS2-----A----',
#  '. Z:-------------',
#  '',
#  'Měl VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'pitnou AAFS4----1A----',
#  'vodu NNFS4-----A----',
#  'sotva Db-------------',
#  'na RR--4----------',
#  'týden NNIS4-----A----',
#  '. Z:-------------',
#  '',
#  'První CrIS4----------',
#  'večer NNIS4-----A----',
#  'jsem VB-S---1P-AA---',
#  'tedy J^-------------',
#  'usnul VpYS---XR-AA---',
#  'v RR--6----------',
#  'písku NNIS6-----A----',
#  ', Z:-------------',
#  'na RR--4----------',
#  'tisíc NNIS4-----A----',
#  'mil NNIXX-----A---8',
#  'daleko Dg-------1A----',
#  'od RR--2----------',
#  'jakékoliv PZFS2---------1',
#  'obydlené AAFS2----1A----',
#  'končiny NNFS2-----A----',
#  '. Z:-------------',
#  '',
#  'Byl VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'opuštěnější AAMS1----2A----',
#  'než J,-------------',
#  'trosečník NNMS1-----A----',
#  'na RR--6----------',
#  'voru NNIS6-----A----',
#  'uprostřed Db-------------',
#  'oceánu NNIS2-----A----',
#  '. Z:-------------',
#  '',
#  'Dovedete VB-P---2P-AA---',
#  'si P7-X3----------',
#  'proto J^-------------',
#  'představit Vf--------A----',
#  ', Z:-------------',
#  'jaké P4NS1----------',
#  'bylo VpNS---XR-AA---',
#  'mé PSNS1-S1------1',
#  'překvapení NNNS1-----A----',
#  ', Z:-------------',
#  'když J,-------------',
#  'mě PH-S4--1-------',
#  'na RR--6----------',
#  'úsvitě NNIS6-----A----',
#  'probudil VpYS---XR-AA---',
#  'zvláštní AAIS4----1A----',
#  'hlásek NNIS4-----A----',
#  ': Z:-------------',
#  '„ Z:-------------',
#  'Prosím VB-S---1P-AA---',
#  'pěkně Dg-------1A----',
#  '. Z:-------------',
#  '. Z:-------------',
#  '. Z:-------------',
#  'nakresli Vi-S---2--A----',
#  'mi PH-S3--1-------',
#  'beránka NNMS4-----A----',
#  '. Z:-------------',
#  '. Z:-------------',
#  '. Z:-------------',
#  '“ Z:-------------',
#  '„ Z:-------------',
#  'Cože PQ--4----------',
#  '? Z:-------------',
#  '“ Z:-------------',
#  '„ Z:-------------',
#  'Nakresli Vi-S---2--A----',
#  'mi PH-S3--1-------',
#  'beránka NNMS4-----A----',
#  '. Z:-------------',
#  '. Z:-------------',
#  '. Z:-------------',
#  '“ Z:-------------',
#  'Vyskočil VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  ', Z:-------------',
#  'jako J,-------------',
#  'by Vc-------------',
#  'do RR--2----------',
#  'mne PP-S2--1-------',
#  'hrom NNIS1-----A----',
#  'uhodil VpYS---XR-AA---',
#  '. Z:-------------',
#  '',
#  'Dobře Dg-------1A----',
#  'jsem VB-S---1P-AA---',
#  'si P7-X3----------',
#  'protřel VpYS---XR-AA---',
#  'oči NNFP4-----A----',
#  '. Z:-------------',
#  '',
#  'Pozorně Dg-------1A----',
#  'jsem VB-S---1P-AA---',
#  'se P7-X4----------',
#  'podíval VpYS---XR-AA---',
#  'a J^-------------',
#  'spatřil VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'prazvláštního AAMS4----1A----',
#  'človíčka NNMS4-----A----',
#  ', Z:-------------',
#  'který P4YS1----------',
#  'si P7-X3----------',
#  'mě PH-S4--1-------',
#  'vážně Dg-------1A----',
#  'prohlížel VpYS---XR-AA---',
#  '. Z:-------------',
#  '',
#  'Toto PDNS1----------',
#  'je VB-S---3P-AA---',
#  'jeho PSXXXZS3-------',
#  'nejlepší AAIS4----3A----',
#  'portrét NNIS4-----A----',
#  ', Z:-------------',
#  'jaký P4IS4----------',
#  'se P7-X4----------',
#  'mi PH-S3--1-------',
#  'podařilo VpNS---XR-AA---',
#  'později Dg-------2A----',
#  'nakreslit Vf--------A----',
#  '. Z:-------------',
#  '',
#  'Má PSFS1-S1------1',
#  'kresba NNFS1-----A----',
#  'ovšem TT-------------',
#  'není VB-S---3P-NA---',
#  'zdaleka Db-------------',
#  'tak Db-------------',
#  'půvabná AAFS1----1A----',
#  'jako J,-------------',
#  'model NNIS1-----A----',
#  '. Z:-------------',
#  '',
#  'Ale J^-------------',
#  'za RR--4----------',
#  'to PDNS4----------',
#  'já PP-S1--1-------',
#  'nemohu VB-S---1P-NA--1',
#  '. Z:-------------',
#  '',
#  'Dospělí NNMP1-----A----',
#  'mě PH-S4--1-------',
#  'odradili VpMP---XR-AA---',
#  'od RR--2----------',
#  'malířské AAFS2----1A----',
#  'kariéry NNFS2-----A----',
#  ', Z:-------------',
#  'když J,-------------',
#  'mi PH-S3--1-------',
#  'bylo VpNS---XR-AA---',
#  'šest Cn-S1----------',
#  'let NNNP2-----A----',
#  ', Z:-------------',
#  'a J^-------------',
#  'proto J^-------------',
#  'jsem VB-S---1P-AA---',
#  'se P7-X4----------',
#  'nenaučil VpYS---XR-NA---',
#  'kreslit Vf--------A----',
#  'nic PW--4----------',
#  'jiného AANS2----1A----',
#  'než J,-------------',
#  'zavřené AAMP4----1A----',
#  'a J^-------------',
#  'otevřené AAMP4----1A----',
#  'hroznýše NNMP4-----A----',
#  '. Z:-------------',
#  '',
#  'Udiveně Dg-------1A----',
#  'jsem VB-S---1P-AA---',
#  'se P7-X4----------',
#  'díval VpYS---XR-AA---',
#  'na RR--4----------',
#  'ten PDIS4----------',
#  'zjev NNIS4-----A----',
#  '. Z:-------------',
#  '',
#  'Považte Vi-P---2--A----',
#  'jen TT-------------',
#  ', Z:-------------',
#  'že J,-------------',
#  'jsem VB-S---1P-AA---',
#  'byl VpYS---XR-AA---',
#  'na RR--4----------',
#  'tisíc ClXS2----------',
#  'mil NNIS4-----A----',
#  'od RR--2----------',
#  'jakéhokoliv PZZS2---------1',
#  'obydleného AAIS2----1A----',
#  'kraje NNIS2-----A----',
#  '. Z:-------------',
#  '',
#  'A J^-------------',
#  'můj PSYS1-S1-------',
#  'človíček NNMS1-----A----',
#  'nevypadal VpYS---XR-NA---',
#  ', Z:-------------',
#  'jako J,-------------',
#  'by Vc-------------',
#  'zabloudil VpYS---XR-AA---',
#  'ani J^-------------',
#  'jako J,-------------',
#  'by Vc-------------',
#  'byl VpYS---XR-AA---',
#  'na RR--4----------',
#  'smrt NNFS4-----A----',
#  'unavený AAMS1----1A----',
#  'nebo J^-------------',
#  'vyhladovělý AAMS1----1A----',
#  ', Z:-------------',
#  'polomrtvý AAMS1----1A----',
#  'žízní NNFS7-----A----',
#  'nebo J^-------------',
#  'na RR--4----------',
#  'smrt NNFS4-----A----',
#  'vylekán VsYS---XX-AP---',
#  '. Z:-------------',
#  '',
#  'Vůbec TT-------------',
#  'nevypadal VpYS---XR-NA---',
#  'jako J,-------------',
#  'dítě NNNS1-----A----',
#  'ztracené AANS1----1A----',
#  'v RR--6----------',
#  'poušti NNFS6-----A----',
#  ', Z:-------------',
#  'na RR--4----------',
#  'tisíc NNIS4-----A----',
#  'mil NNIXX-----A---8',
#  'daleko Dg-------1A----',
#  'od RR--2----------',
#  'nějakého PZZS2----------',
#  'obydleného AAIS2----1A----',
#  'kraje NNIS2-----A----',
#  '. Z:-------------',
#  '',
#  'Když J,-------------',
#  'jsem VB-S---1P-AA---',
#  'konečně Dg-------1A----',
#  'byl VpYS---XR-AA---',
#  'schopen ACYS------A----',
#  'promluvit Vf--------A----',
#  ', Z:-------------',
#  'řekl VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'mu PHZS3--3-------',
#  ': Z:-------------',
#  '„ Z:-------------',
#  'Ale J^-------------',
#  '. Z:-------------',
#  '. Z:-------------',
#  '. Z:-------------',
#  'co PQ--4----------',
#  'tu Db-------------',
#  'děláš VB-S---2P-AA---',
#  '? Z:-------------',
#  '“ Z:-------------',
#  'A J^-------------',
#  'tu PDFS4----------',
#  'mi PH-S3--1-------',
#  'docela Db-------------',
#  'tiše Dg-------1A----',
#  ', Z:-------------',
#  'jako J,-------------',
#  'něco PZ--4----------',
#  'nesmírně Dg-------1N----',
#  'vážného AANS2----1A----',
#  ', Z:-------------',
#  'opakoval VpYS---XR-AA---',
#  ': Z:-------------',
#  '„ Z:-------------',
#  'Prosím VB-S---1P-AA---',
#  'pěkně Dg-------1A----',
#  '. Z:-------------',
#  '. Z:-------------',
#  '. Z:-------------',
#  'nakresli Vi-S---2--A----',
#  'mi PH-S3--1-------',
#  'beránka NNMS4-----A----',
#  '. Z:-------------',
#  '. Z:-------------',
#  '. Z:-------------',
#  '“ Z:-------------',
#  'Když J,-------------',
#  'stojíme VB-P---1P-AA---',
#  'před RR--7----------',
#  'příliš Db-------------',
#  'velkou AAFS7----1A----',
#  'záhadou NNFS7-----A----',
#  ', Z:-------------',
#  'neodvážíme VB-P---1P-NA---',
#  'se P7-X4----------',
#  'neuposlechnout Vf--------N----',
#  '. Z:-------------',
#  '',
#  'Ačkoli J,-------------',
#  'se P7-X4----------',
#  'mi PH-S3--1-------',
#  'to PDNS1----------',
#  'zdálo VpNS---XR-AA---',
#  'zde Db-------------',
#  '– Z:-------------',
#  'na RR--4----------',
#  'tisíce NNIP4-----A----',
#  'mil NNIS4-----A----',
#  'ode RV--2----------',
#  'všech PLXP2----------',
#  'obydlených AANP2----1A----',
#  'míst NNNP2-----A----',
#  'a J^-------------',
#  'v RR--6----------',
#  'nebezpečí NNNS6-----A----',
#  'smrti NNFS2-----A----',
#  '– Z:-------------',
#  'nesmyslné AANS1----1N----',
#  ', Z:-------------',
#  'vytáhl VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'z RR--2----------',
#  'kapsy NNFS2-----A----',
#  'list NNFP2-----A----',
#  'papíru NNIS2-----A----',
#  'plnící AGNS1-----A----',
#  'pero NNNS1-----A----',
#  '. Z:-------------',
#  '',
#  'Ale J^-------------',
#  'tu Db-------------',
#  'jsem VB-S---1P-AA---',
#  'si P7-X3----------',
#  'vzpomněl VpYS---XR-AA---',
#  ', Z:-------------',
#  'že J,-------------',
#  'jsem VB-S---1P-AA---',
#  'studoval VpYS---XR-AA---',
#  'především Db-------------',
#  'zeměpis NNIS4-----A----',
#  ', Z:-------------',
#  'dějepis NNIS4-----A----',
#  ', Z:-------------',
#  'počty NNIP4-----A----',
#  'a J^-------------',
#  'mluvnici NNFS4-----A----',
#  ', Z:-------------',
#  'a J^-------------',
#  'řekl VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'človíčkovi NNMS3-----A----',
#  '( Z:-------------',
#  'trochu Db-------------',
#  'mrzutě Dg-------1A----',
#  ') Z:-------------',
#  ', Z:-------------',
#  'že J,-------------',
#  'neumím VB-S---1P-NA---',
#  'kreslit Vf--------A----',
#  '. Z:-------------',
#  '',
#  'Odpověděl VpYS---XR-AA---',
#  'mi PH-S3--1-------',
#  ': Z:-------------',
#  '„ Z:-------------',
#  'To PDNS1----------',
#  'nevadí VB-S---3P-NA---',
#  '. Z:-------------',
#  '',
#  'Nakresli Vi-S---2--A----',
#  'mi PH-S3--1-------',
#  'beránka NNMS4-----A----',
#  '. Z:-------------',
#  '“ Z:-------------',
#  'Poněvadž J,-------------',
#  'jsem VB-S---1P-AA---',
#  'nikdy Db-------------',
#  'nekreslil VpYS---XR-NA---',
#  'beránka NNMS4-----A----',
#  ', Z:-------------',
#  'nakreslil VpYS---XR-AA---',
#  'jsem VB-S---1P-AA---',
#  'mu PHZS3--3-------',
#  'jednu ClFS4----------',
#  'z RR--2----------',
#  'těch PDXP2----------',
#  'dvou ClXP2----------',
#  'kreseb NNFP2-----A----',
#  ', Z:-------------',
#  'které P4FP4----------',
#  'jsem VB-S---1P-AA---',
#  'uměl VpYS---XR-AA---',
#  '. Z:-------------',
#  '',
#  'Obrázek NNIS1-----A----',
#  'zavřeného AAMS2----1A----',
#  'hroznýše NNMS2-----A----',
#  '. Z:-------------',
#  '',
#  'A J^-------------',
#  'užasl VpYS---XR-AA--1',
#  'jsem VB-S---1P-AA---',
#  ', Z:-------------',
#  'když J,-------------',
#  'jsem VB-S---1P-AA---',
#  'slyšel VpYS---XR-AA---',
#  ', Z:-------------',
#  'jak Db-------------',
#  'mi PH-S3--1-------',
#  'ten PDYS1----------',
#  'človíček NNMS1-----A----',
#  'povídá VB-S---3P-AA---',
#  ': Z:-------------',
#  '„ Z:-------------',
#  'Ale J^-------------',
#  'ne TT-------------',
#  ', Z:-------------',
#  'já PP-S1--1-------',
#  'nechci VB-S---1P-NA---',
#  'slona NNMS4-----A----',
#  'v RR--6----------',
#  'hroznýši NNMS6-----A----',
#  '. Z:-------------',
#  '',
#  'Hroznýš NNMS1-----A----',
#  'je VB-S---3P-AA---',
#  'moc Db-------------',
#  'nebezpečný AAIS1----1N----',
#  'a J^-------------',
#  'slon NNMS1-----A----',
#  'zabere VB-S---3P-AA---',
#  'hodně Dg-------1A----',
#  'místa NNNS2-----A----',
#  '. Z:-------------',
#  '',
#  'U RR--2----------',
#  'mne PP-S2--1-------',
#  'doma Db-------------',
#  'je VB-S---3P-AA---',
#  'všechno PLNS1----------',
#  'malinké AANS1----1A----',
#  '. Z:-------------',
#  '',
#  'Potřebuji VB-S---1P-AA--1',
#  'beránka NNMS4-----A----',
#  '. Z:-------------',
#  '',
#  'Nakresli Vi-S---2--A----',
#  'mi PH-S3--1-------',
#  'beránka NNMS4-----A----',
#  '. Z:-------------',
#  '“ Z:-------------',
#  'Tak Db-------------',
#  'jsem VB-S---1P-AA---',
#  'tedy J^-------------',
#  'kreslil VpYS---XR-AA---',
#  '. Z:-------------',
#  '',
#  '']

# %%
tagged = []
for tok in txt:
    if len(tok) > 0:
        tok = tok.replace(tok[-16:], '/'+tok[-15])
        tagged.append(tok)

# %%
print(tagged[2][:-2])
# Out:
# bylo

# %%
print(tagged)
# Out:
# ['Když/J', 'mi/P', 'bylo/V', 'šest/C', 'let/N', ',/Z', 'viděl/V', 'jsem/V', 'jednou/D', 'nádherný/A', 'obrázek/N', 'v/R', 'knize/N', 'o/R', 'pralese/N', ',/Z', 'která/P', 'se/P', 'jmenovala/V', 'Příběhy/N', 'ze/R', 'života/N', './Z', 'Na/R', 'obrázku/N', 'byl/V', 'hroznýš/N', ',/Z', 'jak/D', 'polyká/V', 'šelmu/N', './Z', 'Tohle/P', 'je/V', 'kopie/N', 'kresby/N', ':/Z', 'V/R', 'knížce/N', 'stálo/V', ':/Z', '„/Z', 'Hroznýši/N', 'svou/P', 'kořist/N', 'nežvýkají/V', ',/Z', 'polykají/V', 'ji/P', 'celou/A', './Z', 'Potom/D', 'se/P', 'nemohou/V', 'ani/J', 'hnout/V', 'a/J', 'celého/A', 'půl/N', 'roku/N', 'spí/V', 'a/J', 'tráví/V', './Z', '“/Z', 'Hodně/D', 'jsem/V', 'tehdy/D', 'přemýšlel/V', 'o/R', 'dobrodružstvích/N', 'v/R', 'džungli/N', 'a/J', 'také/D', 'se/P', 'mně/P', 'podařilo/V', 'nakreslit/V', 'pastelkou/N', 'první/C', 'kresbu/N', './Z', 'Kresbu/N', 'číslo/N', '1/C', './Z', 'Vypadala/V', 'takhle/D', ':/Z', 'Ukázal/V', 'jsem/V', 'své/P', 'veledílo/N', 'dospělým/N', 'a/J', 'ptal/V', 'jsem/V', 'se/P', 'jich/P', ',/Z', 'nahání/V', '-/Z', 'li/T', 'jim/P', 'má/V', 'kresba/N', 'strach/N', './Z', 'Odpověděli/V', 'mi/P', ':/Z', '„/Z', 'Proč/D', 'by/V', 'klobouk/N', 'naháněl/V', 'strach/N', '?/Z', '“/Z', 'Ale/J', 'on/P', 'to/P', 'nebyl/V', 'klobouk/N', './Z', 'Byl/V', 'to/P', 'hroznýš/N', ',/Z', 'jak/D', 'zažívá/V', 'slona/N', './Z', 'Nakreslil/V', 'jsem/V', 'tedy/J', 'vnitřek/N', 'hroznýše/N', ',/Z', 'aby/J', 'to/P', 'dospělí/N', 'pochopili/V', './Z', 'Oni/P', 'totiž/J', 'potřebují/V', 'vždycky/D', 'nějaká/P', 'vysvětlení/N', './Z', 'Má/V', 'kresba/N', 'číslo/N', '2/C', 'vypadala/V', 'takhle/D', ':/Z', 'Dospělí/A', 'mi/P', 'však/J', 'poradili/V', ',/Z', 'aby/J', 'nechal/V', 'toho/P', 'kreslení/N', 'otevřených/A', 'a/J', 'zavřených/A', 'hroznýšů/N', 'a/J', 'zajímal/V', 'se/P', 'raději/D', 'o/R', 'zeměpis/N', ',/Z', 'počty/N', 'a/J', 'mluvnici/N', './Z', 'Tak/D', 'se/P', 'stalo/V', ',/Z', 'že/J', 'jsem/V', 'se/P', 'v/R', 'šesti/C', 'letech/N', 'vzdal/V', 'skvělé/A', 'malířské/A', 'kariéry/N', './Z', 'Neúspěch/N', 'mé/P', 'kresby/N', 'číslo/N', '1/C', 'a/J', 'kresby/N', 'číslo/N', '2/C', 'mě/P', 'odradil/V', './Z', 'Dospělí/A', 'sami/P', 'nikdy/D', 'nic/P', 'nechápou/V', 'a/J', 'děti/N', 'to/P', 'hrozně/D', 'unavuje/V', ',/Z', 'stále/D', 'a/J', 'stále/D', 'jim/P', 'něco/P', 'vysvětlovat/V', './Z', 'Musel/V', 'jsem/V', 'si/P', 'tedy/J', 'vybrat/V', 'jiné/A', 'povolání/N', 'a/J', 'naučil/V', 'jsem/V', 'se/P', 'řídit/V', 'letadlo/N', './Z', 'Létal/V', 'jsem/V', 'tak/D', 'trochu/D', 'po/R', 'celém/A', 'světě/N', './Z', 'A/J', 'pravda/N', 'je/V', ',/Z', 'že/J', 'mi/P', 'zeměpis/N', 'hodně/D', 'posloužil/V', './Z', 'Dovedl/V', 'jsem/V', 'na/R', 'první/C', 'pohled/N', 'rozeznat/V', 'Čínu/N', 'od/R', 'Arizony/N', './Z', 'Je/V', 'to/P', 'velice/D', 'užitečné/A', ',/Z', 'když/J', 'člověk/N', 'v/R', 'noci/N', 'zabloudí/V', './Z', 'A/J', 'tak/D', 'jsem/V', 'se/P', 'v/R', 'životě/N', 'setkal/V', 'se/R', 'spoustou/N', 'vážných/A', 'lidí/N', './Z', 'Žil/V', 'jsem/V', 'hodně/D', 's/R', 'dospělými/N', ',/Z', 'poznal/V', 'jsem/V', 'je/P', 'velice/D', 'zblízka/D', './Z', 'Ale/J', 'mé/P', 'mínění/N', 'o/R', 'nich/P', 'se/P', 'valně/D', 'nezměnilo/V', './Z', 'Když/J', 'jsem/V', 'mezi/R', 'nimi/P', 'potkal/V', 'někoho/P', ',/Z', 'kdo/P', 'se/P', 'mi/P', 'zdál/V', 'trochu/D', 'bystrý/A', ',/Z', 'ověřil/V', 'jsem/V', 'si/P', 'na/R', 'něm/P', 'svou/P', 'zkušenost/N', 's/R', 'kresbou/N', 'číslo/N', '1/C', ',/Z', 'kterou/P', 'mám/V', 'stále/D', 'schovanou/A', './Z', 'Chtěl/V', 'jsem/V', 'vědět/V', ',/Z', 'je/V', '-/Z', 'li/T', 'opravdu/D', 'chápavý/A', './Z', 'Ale/J', 'vždycky/D', 'mi/P', 'odpověděl/V', ':/Z', '„/Z', 'To/P', 'je/V', 'klobouk/N', './Z', '“/Z', 'Nepovídal/V', 'jsem/V', 'mu/P', 'tedy/J', 'ani/J', 'o/R', 'hroznýších/N', ',/Z', 'ani/J', 'o/R', 'pralesích/N', ',/Z', 'ani/J', 'o/R', 'hvězdách/N', './Z', 'Přizpůsobil/V', 'jsem/V', 'se/P', 'mu/P', './Z', 'Mluvil/V', 'jsem/V', 's/R', 'ním/P', 'o/R', 'bridži/N', ',/Z', 'golfu/N', ',/Z', 'politice/N', 'a/J', 'o/ ...

# %%
with open('princ_tagged.txt', 'x') as princ:
    for tok in tagged:
        princ.write(tok+' ')

# %%
with open ('princ.txt', 'x') as prnc:
    for tok in tagged:
        prnc.write(tok[:-3]+' ')

# %%
with open('princ_tagged.txt', 'r') as princ:
    princ = princ.read()

# %%
princ
# Out:
# 'Když/J mi/P bylo/V šest/C let/N ,/Z viděl/V jsem/V jednou/D nádherný/A obrázek/N v/R knize/N o/R pralese/N ,/Z která/P se/P jmenovala/V Příběhy/N ze/R života/N ./Z Na/R obrázku/N byl/V hroznýš/N ,/Z jak/D polyká/V šelmu/N ./Z Tohle/P je/V kopie/N kresby/N :/Z V/R knížce/N stálo/V :/Z „/Z Hroznýši/N svou/P kořist/N nežvýkají/V ,/Z polykají/V ji/P celou/A ./Z Potom/D se/P nemohou/V ani/J hnout/V a/J celého/A půl/N roku/N spí/V a/J tráví/V ./Z “/Z Hodně/D jsem/V tehdy/D přemýšlel/V o/R dobrodružstvích/N v/R džungli/N a/J také/D se/P mně/P podařilo/V nakreslit/V pastelkou/N první/C kresbu/N ./Z Kresbu/N číslo/N 1/C ./Z Vypadala/V takhle/D :/Z Ukázal/V jsem/V své/P veledílo/N dospělým/N a/J ptal/V jsem/V se/P jich/P ,/Z nahání/V -/Z li/T jim/P má/V kresba/N strach/N ./Z Odpověděli/V mi/P :/Z „/Z Proč/D by/V klobouk/N naháněl/V strach/N ?/Z “/Z Ale/J on/P to/P nebyl/V klobouk/N ./Z Byl/V to/P hroznýš/N ,/Z jak/D zažívá/V slona/N ./Z Nakreslil/V jsem/V tedy/J vnitřek/N hroznýše/N ,/Z aby/J to/P dospělí/N pochopili/V ./Z Oni/P totiž/J potřebují/V vždycky/D nějaká/P vysvětlení/N ./Z Má/V kresba/N číslo/N 2/C vypadala/V takhle/D :/Z Dospělí/A mi/P však/J poradili/V ,/Z aby/J nechal/V toho/P kreslení/N otevřených/A a/J zavřených/A hroznýšů/N a/J zajímal/V se/P raději/D o/R zeměpis/N ,/Z počty/N a/J mluvnici/N ./Z Tak/D se/P stalo/V ,/Z že/J jsem/V se/P v/R šesti/C letech/N vzdal/V skvělé/A malířské/A kariéry/N ./Z Neúspěch/N mé/P kresby/N číslo/N 1/C a/J kresby/N číslo/N 2/C mě/P odradil/V ./Z Dospělí/A sami/P nikdy/D nic/P nechápou/V a/J děti/N to/P hrozně/D unavuje/V ,/Z stále/D a/J stále/D jim/P něco/P vysvětlovat/V ./Z Musel/V jsem/V si/P tedy/J vybrat/V jiné/A povolání/N a/J naučil/V jsem/V se/P řídit/V letadlo/N ./Z Létal/V jsem/V tak/D trochu/D po/R celém/A světě/N ./Z A/J pravda/N je/V ,/Z že/J mi/P zeměpis/N hodně/D posloužil/V ./Z Dovedl/V jsem/V na/R první/C pohled/N rozeznat/V Čínu/N od/R Arizony/N ./Z Je/V to/P velice/D užitečné/A ,/Z když/J člověk/N v/R noci/N zabloudí/V ./Z A/J tak/D jsem/V se/P v/R životě/N setkal/V se/R spoustou/N vážných/A lidí/N ./Z Žil/V jsem/V hodně/D s/R dospělými/N ,/Z poznal/V jsem/V je/P velice/D zblízka/D ./Z Ale/J mé/P mínění/N o/R nich/P se/P valně/D nezměnilo/V ./Z Když/J jsem/V mezi/R nimi/P potkal/V někoho/P ,/Z kdo/P se/P mi/P zdál/V trochu/D bystrý/A ,/Z ověřil/V jsem/V si/P na/R něm/P svou/P zkušenost/N s/R kresbou/N číslo/N 1/C ,/Z kterou/P mám/V stále/D schovanou/A ./Z Chtěl/V jsem/V vědět/V ,/Z je/V -/Z li/T opravdu/D chápavý/A ./Z Ale/J vždycky/D mi/P odpověděl/V :/Z „/Z To/P je/V klobouk/N ./Z “/Z Nepovídal/V jsem/V mu/P tedy/J ani/J o/R hroznýších/N ,/Z ani/J o/R pralesích/N ,/Z ani/J o/R hvězdách/N ./Z Přizpůsobil/V jsem/V se/P mu/P ./Z Mluvil/V jsem/V s/R ním/P o/R bridži/N ,/Z golfu/N ,/Z politice/N a/J o/R kravatách/N ./Z A/J dospělý/N byl/V velice/D spokojen/A ,/Z že/J poznal/V tak/D rozuumného/A člověka/N ./Z Tak/D jsem/V žil/V sám/P a/J neměl/V jsem/V nikoho/P ,/Z s/R kým/P bych/V si/P mohl/V opravdu/D popovídat/V ./Z Tu/P se/P mi/P jednou/D před/R šesti/C lety/N v/R poušti/N na/R Sahaře/N porouchal/V motor/N ./Z Něco/P se/P v/R něm/P polámalo/V ./Z A/J poněvadž/J jsem/V neměl/V s/R sebou/P mechanika/N ani/J cestující/A ,/Z chtěl/V jsem/V se/P do/R té/P nesnadné/A opravy/N pustit/V sám/P ./Z Byla/V to/P pro/R mne/P otázka/N života/N nebo/J smrti/N ./Z Měl/V jsem/V pitnou/A vodu/N sotva/D na/R týden/N ./Z První/C večer/N jsem/V tedy/J usnul/V v/R písku/N ,/Z na/R tisíc/N mil/N daleko/D od/R jakékoliv/P obydlené/A končiny/N ./Z Byl/V jsem/V opuštěnější/A než/J trosečník/N na/R voru/N uprostřed/D oceánu/N ./Z Dovedete/V si/P proto/J představit/V ,/Z jaké/P bylo/V mé/P překvapení/N ,/Z když/J mě/P na/R úsvitě/N probudil/V zvláštní/A hlásek/N :/Z „/Z Prosím/V pěkně/D ./Z ./Z ./Z nakresli/V mi/P beránka/N ./Z ./Z ./Z “/Z „/Z Cože/P ?/Z “/Z „/Z Nakresli/V mi/P beránka/N ./Z ./Z ./Z “/Z Vyskočil/V jsem/V ,/Z jako/J by/V do/R mne/P hrom/N uhodil/V ./Z Dobře/D jsem/V si/P protřel/V o ...

# %% [markdown]
# ## 8 Morfologická analýza s použitím regulárních výrazů
#
# V této sekci budete mít za úkol naprogramovat morfologický analyzátor, který pomocí regulárních výrazů rozhodne, do jakého slovního druhu spadají slovní tvary vybraného textu. Než se pustíte do programování, připomeňte si práci s knihovnou re a regulárními výrazy (užitečné odkazy jsou k dispozici v sekci 3 tohoto notebooku).
#
# **Úkol:** Vytvořte program, který načte data ze souboru a ke každému slovu přiřadí slovní druh.
#
# Na konci tohoto notebooku je funkce `accuracy`, která vyhodnotí, jak je váš analyzátor přesný. Dodržte formát předpřipraveného textu z předešlé sekce, aby vám porovnání fungovalo.
#
# K přiřazení slovních druhů použijte regulární výrazy. Projděte si vzorový text, případně text dle vašeho výběru a najděte alespoň nějaké prvky, které se shodují u určitých slovních druhů. Na základě vašeho pozorování vytvořte regulární výrazy a slova označte.
#
# Program vhodně rozdělte na funkce.

# %%
def open_text(text):
    """ Otevři text předpřipravený ke značkování a vrať seznam slovních tvarů. """
    
    with open(text, 'r') as txt:
        txt = txt.read()
        txt = txt.split()
        
    return txt

# %%
text = open_text('data/princ.txt')

# %%
import string, re

# %%
def tag_text(text):
    """  """
    
    #Regulární výrazy
    punct = re.compile(r'[„“]')
    adj = re.compile(r'ný$')
    
    #Označkovaný seznam
    tagged = []
    
    for tok in text:
        if tok in string.punctuation or re.search(punct, tok):
            tagged.append(tok+'/Z')
            
        elif re.search(adj, tok):
            tagged.append(tok+'/A')
            
        else:
            tagged.append(tok+'/N')
            
    return tagged

# %%
tagged = tag_text(text)

# %%
tagged
# Out:
# ['Když/N',
#  'mi/N',
#  'bylo/N',
#  'šest/N',
#  'let/N',
#  ',/Z',
#  'viděl/N',
#  'jsem/N',
#  'jednou/N',
#  'nádherný/A',
#  'obrázek/N',
#  'v/N',
#  'knize/N',
#  'o/N',
#  'pralese/N',
#  ',/Z',
#  'která/N',
#  'se/N',
#  'jmenovala/N',
#  'Příběhy/N',
#  'ze/N',
#  'života/N',
#  './Z',
#  'Na/N',
#  'obrázku/N',
#  'byl/N',
#  'hroznýš/N',
#  ',/Z',
#  'jak/N',
#  'polyká/N',
#  'šelmu/N',
#  './Z',
#  'Tohle/N',
#  'je/N',
#  'kopie/N',
#  'kresby/N',
#  ':/Z',
#  'V/N',
#  'knížce/N',
#  'stálo/N',
#  ':/Z',
#  '„/Z',
#  'Hroznýši/N',
#  'svou/N',
#  'kořist/N',
#  'nežvýkají/N',
#  ',/Z',
#  'polykají/N',
#  'ji/N',
#  'celou/N',
#  './Z',
#  'Potom/N',
#  'se/N',
#  'nemohou/N',
#  'ani/N',
#  'hnout/N',
#  'a/N',
#  'celého/N',
#  'půl/N',
#  'roku/N',
#  'spí/N',
#  'a/N',
#  'tráví/N',
#  './Z',
#  '“/Z',
#  'Hodně/N',
#  'jsem/N',
#  'tehdy/N',
#  'přemýšlel/N',
#  'o/N',
#  'dobrodružstvích/N',
#  'v/N',
#  'džungli/N',
#  'a/N',
#  'také/N',
#  'se/N',
#  'mně/N',
#  'podařilo/N',
#  'nakreslit/N',
#  'pastelkou/N',
#  'první/N',
#  'kresbu/N',
#  './Z',
#  'Kresbu/N',
#  'číslo/N',
#  '1/N',
#  './Z',
#  'Vypadala/N',
#  'takhle/N',
#  ':/Z',
#  'Ukázal/N',
#  'jsem/N',
#  'své/N',
#  'veledílo/N',
#  'dospělým/N',
#  'a/N',
#  'ptal/N',
#  'jsem/N',
#  'se/N',
#  'jich/N',
#  ',/Z',
#  'nahání/N',
#  '-/Z',
#  'li/N',
#  'jim/N',
#  'má/N',
#  'kresba/N',
#  'strach/N',
#  './Z',
#  'Odpověděli/N',
#  'mi/N',
#  ':/Z',
#  '„/Z',
#  'Proč/N',
#  'by/N',
#  'klobouk/N',
#  'naháněl/N',
#  'strach/N',
#  '?/Z',
#  '“/Z',
#  'Ale/N',
#  'on/N',
#  'to/N',
#  'nebyl/N',
#  'klobouk/N',
#  './Z',
#  'Byl/N',
#  'to/N',
#  'hroznýš/N',
#  ',/Z',
#  'jak/N',
#  'zažívá/N',
#  'slona/N',
#  './Z',
#  'Nakreslil/N',
#  'jsem/N',
#  'tedy/N',
#  'vnitřek/N',
#  'hroznýše/N',
#  ',/Z',
#  'aby/N',
#  'to/N',
#  'dospělí/N',
#  'pochopili/N',
#  './Z',
#  'Oni/N',
#  'totiž/N',
#  'potřebují/N',
#  'vždycky/N',
#  'nějaká/N',
#  'vysvětlení/N',
#  './Z',
#  'Má/N',
#  'kresba/N',
#  'číslo/N',
#  '2/N',
#  'vypadala/N',
#  'takhle/N',
#  ':/Z',
#  'Dospělí/N',
#  'mi/N',
#  'však/N',
#  'poradili/N',
#  ',/Z',
#  'aby/N',
#  'nechal/N',
#  'toho/N',
#  'kreslení/N',
#  'otevřených/N',
#  'a/N',
#  'zavřených/N',
#  'hroznýšů/N',
#  'a/N',
#  'zajímal/N',
#  'se/N',
#  'raději/N',
#  'o/N',
#  'zeměpis/N',
#  ',/Z',
#  'počty/N',
#  'a/N',
#  'mluvnici/N',
#  './Z',
#  'Tak/N',
#  'se/N',
#  'stalo/N',
#  ',/Z',
#  'že/N',
#  'jsem/N',
#  'se/N',
#  'v/N',
#  'šesti/N',
#  'letech/N',
#  'vzdal/N',
#  'skvělé/N',
#  'malířské/N',
#  'kariéry/N',
#  './Z',
#  'Neúspěch/N',
#  'mé/N',
#  'kresby/N',
#  'číslo/N',
#  '1/N',
#  'a/N',
#  'kresby/N',
#  'číslo/N',
#  '2/N',
#  'mě/N',
#  'odradil/N',
#  './Z',
#  'Dospělí/N',
#  'sami/N',
#  'nikdy/N',
#  'nic/N',
#  'nechápou/N',
#  'a/N',
#  'děti/N',
#  'to/N',
#  'hrozně/N',
#  'unavuje/N',
#  ',/Z',
#  'stále/N',
#  'a/N',
#  'stále/N',
#  'jim/N',
#  'něco/N',
#  'vysvětlovat/N',
#  './Z',
#  'Musel/N',
#  'jsem/N',
#  'si/N',
#  'tedy/N',
#  'vybrat/N',
#  'jiné/N',
#  'povolání/N',
#  'a/N',
#  'naučil/N',
#  'jsem/N',
#  'se/N',
#  'řídit/N',
#  'letadlo/N',
#  './Z',
#  'Létal/N',
#  'jsem/N',
#  'tak/N',
#  'trochu/N',
#  'po/N',
#  'celém/N',
#  'světě/N',
#  './Z',
#  'A/N',
#  'pravda/N',
#  'je/N',
#  ',/Z',
#  'že/N',
#  'mi/N',
#  'zeměpis/N',
#  'hodně/N',
#  'posloužil/N',
#  './Z',
#  'Dovedl/N',
#  'jsem/N',
#  'na/N',
#  'první/N',
#  'pohled/N',
#  'rozeznat/N',
#  'Čínu/N',
#  'od/N',
#  'Arizony/N',
#  './Z',
#  'Je/N',
#  'to/N',
#  'velice/N',
#  'užitečné/N',
#  ',/Z',
#  'když/N',
#  'člověk/N',
#  'v/N',
#  'noci/N',
#  'zabloudí/N',
#  './Z',
#  'A/N',
#  'tak/N',
#  'jsem/N',
#  'se/N',
#  'v/N',
#  'životě/N',
#  'setkal/N',
#  'se/N',
#  'spoustou/N',
#  'vážných/N',
#  'lidí/N',
#  './Z',
#  'Žil/N',
#  'jsem/N',
#  'hodně/N',
#  's/N',
#  'dospělými/N',
#  ',/Z',
#  'poznal/N',
#  'jsem/N',
#  'je/N',
#  'velice/N',
#  'zblízka/N',
#  './Z',
#  'Ale/N',
#  'mé/N',
#  'mínění/N',
#  'o/N',
#  'nich/N',
#  'se/N',
#  'valně/N',
#  'nezměnilo/N',
#  './Z',
#  'Když/N',
#  'jsem/N',
#  'mezi/N',
#  'nimi/N',
#  'potkal/N',
#  'někoho/N',
#  ',/Z',
#  'kdo/N',
#  'se/N',
#  'mi/N',
#  'zdál/N',
#  'trochu/N',
#  'bystrý/N',
#  ',/Z',
#  'ověřil/N',
#  'jsem/N',
#  'si/N',
#  'na/N',
#  'něm/N',
#  'svou/N',
#  'zkušenost/N',
#  's/N',
#  'kresbou/N',
#  'číslo/N',
#  '1/N',
#  ',/Z',
#  'kterou/N',
#  'mám/N',
#  'stále/N',
#  'schovanou/N',
#  './Z',
#  'Chtěl/N',
#  'jsem/N',
#  'vědět/N',
#  ',/Z',
#  'je/N',
#  '-/Z',
#  'li/N',
#  'opravdu/N',
#  'chápavý/N',
#  './Z',
#  'Ale/N',
#  'vždycky/N',
#  'mi/N',
#  'odpověděl/N',
#  ':/Z',
#  '„/Z',
#  'To/N',
#  'je/N',
#  'klobouk/N',
#  './Z',
#  '“/Z',
#  'Nepovídal/N',
#  'jsem/N',
#  'mu/N',
#  'tedy/N',
#  'ani/N',
#  'o/N',
#  'hroznýších/N',
#  ',/Z',
#  'ani/N',
#  'o/N',
#  'pralesích/N',
#  ',/Z',
#  'ani/N',
#  'o/N',
#  'hvězdách/N',
#  './Z',
#  'Přizpůsobil/N',
#  'jsem/N',
#  'se/N',
#  'mu/N',
#  './Z',
#  'Mluvil/N',
#  'jsem/N',
#  's/N',
#  'ním/N',
#  'o/N',
#  'bridži/N',
#  ',/Z',
#  'golfu/N',
#  ',/Z',
#  'politice/N',
#  'a/N',
#  'o/N',
#  'kravatách/N',
#  './Z',
#  'A/N',
#  'dospělý/N',
#  'byl/N',
#  'velice/N',
#  'spokojen/N',
#  ',/Z',
#  'že/N',
#  'poznal/N',
#  'tak/N',
#  'rozuumného/N',
#  'člověka/N',
#  './Z',
#  'Tak/N',
#  'jsem/N',
#  'žil/N',
#  'sám/N',
#  'a/N',
#  'neměl/N',
#  'jsem/N',
#  'nikoho/N',
#  ',/Z',
#  's/N',
#  'kým/N',
#  'bych/N',
#  'si/N',
#  'mohl/N',
#  'opravdu/N',
#  'popovídat/N',
#  './Z',
#  'Tu/N',
#  'se/N',
#  'mi/N',
#  'jednou/N',
#  'před/N',
#  'šesti/N',
#  'lety/N',
#  'v/N',
#  'poušti/N',
#  'na/N',
#  'Sahaře/N',
#  'porouchal/N',
#  'motor/N',
#  './Z',
#  'Něco/N',
#  'se/N',
#  'v/N',
#  'něm/N',
#  'polámalo/N',
#  './Z',
#  'A/N',
#  'poněvadž/N',
#  'jsem/N',
#  'neměl/N',
#  's/N',
#  'sebou/N',
#  'mechanika/N',
#  'ani/N',
#  'cestující/N',
#  ',/Z',
#  'chtěl/N',
#  'jsem/N',
#  'se/N',
#  'do/N',
#  'té/N',
#  'nesnadné/N',
#  'opravy/N',
#  'pustit/N',
#  'sám/N',
#  './Z',
#  'Byla/N',
#  'to/N',
#  'pro/N',
#  'mne/N',
#  'otázka/N',
#  'života/N',
#  'nebo/N',
#  'smrti/N',
#  './Z',
#  'Měl/N',
#  'jsem/N',
#  'pitnou/N',
#  'vodu/N',
#  'sotva/N',
#  'na/N',
#  'týden/N',
#  './Z',
#  'První/N',
#  'večer/N',
#  'jsem/N',
#  'tedy/N',
#  'usnul/N',
#  'v/N',
#  'písku/N',
#  ',/Z',
#  'na/N',
#  'tisíc/N',
#  'mil/N',
#  'daleko/N',
#  'od/N',
#  'jakékoliv/N',
#  'obydlené/N',
#  'končiny/N',
#  './Z',
#  'Byl/N',
#  'jsem/N',
#  'opuštěnější/N',
#  'než/N',
#  'trosečník/N',
#  'na/N',
#  'voru/N',
#  'uprostřed/N',
#  'oceánu/N',
#  './Z',
#  'Dovedete/N',
#  'si/N',
#  'proto/N',
#  'představit/N',
#  ',/Z',
#  'jaké/N',
#  'bylo/N',
#  'mé/N',
#  'překvapení/N',
#  ',/Z',
#  'když/N',
#  'mě/N',
#  'na/N',
#  'úsvitě/N',
#  'probudil/N',
#  'zvláštní/N',
#  'hlásek/N',
#  ':/Z',
#  '„/Z',
#  'Prosím/N',
#  'pěkně/N',
#  './Z',
#  './Z',
#  './Z',
#  'nakresli/N',
#  'mi/N',
#  'beránka/N',
#  './Z',
#  './Z',
#  './Z',
#  '“/Z',
#  '„/Z',
#  'Cože/N',
#  '?/Z',
#  '“/Z',
#  '„/Z',
#  'Nakresli/N',
#  'mi/N',
#  'beránka/N',
#  './Z',
#  './Z',
#  './Z',
#  '“/Z',
#  'Vyskočil/N',
#  'jsem/N',
#  ',/Z',
#  'jako/N',
#  'by/N',
#  'do/N',
#  'mne/N',
#  'hrom/N',
#  'uhodil/N',
#  './Z',
#  'Dobře/N',
#  'jsem/N',
#  'si/N',
#  'protřel/N',
#  'oči/N',
#  './Z',
#  'Pozorně/N',
#  'jsem/N',
#  'se/N',
#  'podíval/N',
#  'a/N',
#  'spatřil/N',
#  'jsem/N',
#  'prazvláštního/N',
#  'človíčka/N',
#  ',/Z',
#  'který/N',
#  'si/N',
#  'mě/N',
#  'vážně/N',
#  'prohlížel/N',
#  './Z',
#  'Toto/N',
#  'je/N',
#  'jeho/N',
#  'nejlepší/N',
#  'portrét/N',
#  ',/Z',
#  'jaký/N',
#  'se/N',
#  'mi/N',
#  'podařilo/N',
#  'později/N',
#  'nakreslit/N',
#  './Z',
#  'Má/N',
#  'kresba/N',
#  'ovšem/N',
#  'není/N',
#  'zdaleka/N',
#  'tak/N',
#  'půvabná/N',
#  'jako/N',
#  'model/N',
#  './Z',
#  'Ale/N',
#  'za/N',
#  'to/N',
#  'já/N',
#  'nemohu/N',
#  './Z',
#  'Dospělí/N',
#  'mě/N',
#  'odradili/N',
#  'od/N',
#  'malířské/N',
#  'kariéry/N',
#  ',/Z',
#  'když/N',
#  'mi/N',
#  'bylo/N',
#  'šest/N',
#  'let/N',
#  ',/Z',
#  'a/N',
#  'proto/N',
#  'jsem/N',
#  'se/N',
#  'nenaučil/N',
#  'kreslit/N',
#  'nic/N',
#  'jiného/N',
#  'než/N',
#  'zavřené/N',
#  'a/N',
#  'otevřené/N',
#  'hroznýše/N',
#  './Z',
#  'Udiveně/N',
#  'jsem/N',
#  'se/N',
#  'díval/N',
#  'na/N',
#  'ten/N',
#  'zjev/N',
#  './Z',
#  'Považte/N',
#  'jen/N',
#  ',/Z',
#  'že/N',
#  'jsem/N',
#  'byl/N',
#  'na/N',
#  'tisíc/N',
#  'mil/N',
#  'od/N',
#  'jakéhokoliv/N',
#  'obydleného/N',
#  'kraje/N',
#  './Z',
#  'A/N',
#  'můj/N',
#  'človíček/N',
#  'nevypadal/N',
#  ',/Z',
#  'jako/N',
#  'by/N',
#  'zabloudil/N',
#  'ani/N',
#  'jako/N',
#  'by/N',
#  'byl/N',
#  'na/N',
#  'smrt/N',
#  'unavený/A',
#  'nebo/N',
#  'vyhladovělý/N',
#  ',/Z',
#  'polomrtvý/N',
#  'žízní/N',
#  'nebo/N',
#  'na/N',
#  'smrt/N',
#  'vylekán/N',
#  './Z',
#  'Vůbec/N',
#  'nevypadal/N',
#  'jako/N',
#  'dítě/N',
#  'ztracené/N',
#  'v/N',
#  'poušti/N',
#  ',/Z',
#  'na/N',
#  'tisíc/N',
#  'mil/N',
#  'daleko/N',
#  'od/N',
#  'nějakého/N',
#  'obydleného/N',
#  'kraje/N',
#  './Z',
#  'Když/N',
#  'jsem/N',
#  'konečně/N',
#  'byl/N',
#  'schopen/N',
#  'promluvit/N',
#  ',/Z',
#  'řekl/N',
#  'jsem/N',
#  'mu/N',
#  ':/Z',
#  '„/Z',
#  'Ale/N',
#  './Z',
#  './Z',
#  './Z',
#  'co/N',
#  'tu/N',
#  'děláš/N',
#  '?/Z',
#  '“/Z',
#  'A/N',
#  'tu/N',
#  'mi/N',
#  'docela/N',
#  'tiše/N',
#  ',/Z',
#  'jako/N',
#  'něco/N',
#  'nesmírně/N',
#  'vážného/N',
#  ',/Z',
#  'opakoval/N',
#  ':/Z',
#  '„/Z',
#  'Prosím/N',
#  'pěkně/N',
#  './Z',
#  './Z',
#  './Z',
#  'nakresli/N',
#  'mi/N',
#  'beránka/N',
#  './Z',
#  './Z',
#  './Z',
#  '“/Z',
#  'Když/N',
#  'stojíme/N',
#  'před/N',
#  'příliš/N',
#  'velkou/N',
#  'záhadou/N',
#  ',/Z',
#  'neodvážíme/N',
#  'se/N',
#  'neuposlechnout/N',
#  './Z',
#  'Ačkoli/N',
#  'se/N',
#  'mi/N',
#  'to/N',
#  'zdálo/N',
#  'zde/N',
#  '–/N',
#  'na/N',
#  'tisíce/N',
#  'mil/N',
#  'ode/N',
#  'všech/N',
#  'obydlených/N',
#  'míst/N',
#  'a/N',
#  'v/N',
#  'nebezpečí/N',
#  'smrti/N',
#  '–/N',
#  'nesmyslné/N',
#  ',/Z',
#  'vytáhl/N',
#  'jsem/N',
#  'z/N',
#  'kapsy/N',
#  'list/N',
#  'papíru/N',
#  'plnící/N',
#  'pero/N',
#  './Z',
#  'Ale/N',
#  'tu/N',
#  'jsem/N',
#  'si/N',
#  'vzpomněl/N',
#  ',/Z',
#  'že/N',
#  'jsem/N',
#  'studoval/N',
#  'především/N',
#  'zeměpis/N',
#  ',/Z',
#  'dějepis/N',
#  ',/Z',
#  'počty/N',
#  'a/N',
#  'mluvnici/N',
#  ',/Z',
#  'a/N',
#  'řekl/N',
#  'jsem/N',
#  'človíčkovi/N',
#  '(/Z',
#  'trochu/N',
#  'mrzutě/N',
#  ')/Z',
#  ',/Z',
#  'že/N',
#  'neumím/N',
#  'kreslit/N',
#  './Z',
#  'Odpověděl/N',
#  'mi/N',
#  ':/Z',
#  '„/Z',
#  'To/N',
#  'nevadí/N',
#  './Z',
#  'Nakresli/N',
#  'mi/N',
#  'beránka/N',
#  './Z',
#  '“/Z',
#  'Poněvadž/N',
#  'jsem/N',
#  'nikdy/N',
#  'nekreslil/N',
#  'beránka/N',
#  ',/Z',
#  'nakreslil/N',
#  'jsem/N',
#  'mu/N',
#  'jednu/N',
#  'z/N',
#  'těch/N',
#  'dvou/N',
#  'kreseb/N',
#  ',/Z',
#  'které/N',
#  'jsem/N',
#  'uměl/N',
#  './Z',
#  'Obrázek/N',
#  'zavřeného/N',
#  'hroznýše/N',
#  './Z',
#  'A/N',
#  'užasl/N',
#  'jsem/N',
#  ',/Z',
#  'když/N',
#  'jsem/N',
#  'slyšel/N',
#  ',/Z',
#  'jak/N',
#  'mi/N',
#  'ten/N',
#  'človíček/N',
#  'povídá/N',
#  ':/Z',
#  '„/Z',
#  'Ale/N',
#  'ne/N',
#  ',/Z',
#  'já/N',
#  'nechci/N',
#  'slona/N',
#  'v/N',
#  'hroznýši/N',
#  './Z',
#  'Hroznýš/N',
#  'je/N',
#  'moc/N',
#  'nebezpečný/A',
#  'a/N',
#  'slon/N',
#  'zabere/N',
#  'hodně/N',
#  'místa/N',
#  './Z',
#  'U/N',
#  'mne/N',
#  'doma/N',
#  'je/N',
#  'všechno/N',
#  'malinké/N',
#  './Z',
#  'Potřebuji/N',
#  'beránka/N',
#  './Z',
#  'Nakresli/N',
#  'mi/N',
#  'beránka/N',
#  './Z',
#  '“/Z',
#  'Tak/N',
#  'jsem/N',
#  'tedy/N',
#  'kreslil/N',
#  './Z']

# %% [markdown]
# Spusťte následující dvě buňky a zjistěte, jak je váš analyzátor přesný.
#
# accuracy = (correctly predicted class / total testing class) × 100%
#
# Aby porovnání fungovalo, musí váš analyzátor vrátit výsledný text v seznamu, jehož prvky jsou řetězce ve formátu `slovo/slovní_druh`, např. `seznam = ['obrázek/N', 'je/V', 'hezký/A']`. Váš analyzátor musí dodržet velká a malá písmena a značky slovních druhů se musí shodovat se značkami pozičního systému. Více o značkách [zde](https://wiki.korpus.cz/doku.php/seznamy:tagy#poziceslovni_druh). Také si dejte pozor, aby délka vašeho výsledného textu (potažmo seznamu) byla stejná jako délka správně označkovaného textu.

# %%
def accuracy(tagged_text, correct_text):
    """ aaa """
    
    correct_text = open_text(correct_text)
    correct_count = 0
    
    for i in range(len(correct_text)):
        if tagged_text[i] == correct_text[i]:
            correct_count += 1
    
    return correct_count/len(correct_text) * 100

# %%
accuracy(tagged, 'data/princ_tagged.txt')
# Out:
# 35.55070883315158
